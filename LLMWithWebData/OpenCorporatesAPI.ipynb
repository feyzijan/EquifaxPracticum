# %%
import pandas as pd
from dotenv import load_dotenv
import os
import requests
import random

# %%
endpoint = "https://api.opencorporates.com/"
load_dotenv()
api_key = os.getenv("OPENCORPORATES_API_KEY")
# Api endpoints
# GET companies/:jurisdiction_code/:company_number
# https://api.opencorporates.com/v0.4/companies/gb/00102498?sparse=true

# companies/search

# %% [markdown]
# Example code from Gemini

# %%
def get_random_companies(state, api_key, num_companies=10):
  """
  Downloads attributes for a random subset of active companies in a given US state
  and returns the data in a pandas DataFrame.

  Args:
    state: The US state abbreviation (e.g., "CA" for California).
    api_key: Your OpenCorporates API key.
    num_companies: The number of random companies to retrieve.

  Returns:
    A pandas DataFrame containing the company data.
  """

  # Search for active companies in the specified state
  search_url = f"https://api.opencorporates.com/v0.4/companies/search"
  params = {
      "q": "*",  # Search for all companies
      "jurisdiction_code": f"us_{state.lower()}",
      "current_status": "Active",  # Filter for active companies
      "api_token": api_key,
      "per_page": 100  # Get maximum results per page
  }
  response = requests.get(search_url, params=params)
  response.raise_for_status()  # Raise an exception for bad status codes
  search_data = response.json()

  total_companies = search_data["results"]["total_count"]
  if total_companies == 0:
    return pd.DataFrame()  # Return an empty DataFrame if no companies found

  # Generate random indices to select a subset of companies
  random_indices = random.sample(range(total_companies), min(num_companies, total_companies))

  companies = []
  current_page = 1
  companies_retrieved = 0

  # Iterate through pages and retrieve company details
  while companies_retrieved < len(random_indices):
    params["page"] = current_page
    response = requests.get(search_url, params=params)
    response.raise_for_status()
    search_data = response.json()

    for i, company_data in enumerate(search_data["results"]["companies"]):
      global_index = (current_page - 1) * 100 + i
      if global_index in random_indices:
        company_number = company_data["company"]["company_number"]
        company_url = f"https://api.opencorporates.com/v0.4/companies/us_{state.lower()}/{company_number}"
        params = {"api_token": api_key}
        response = requests.get(company_url, params=params)
        response.raise_for_status()
        company_details = response.json()["results"]["company"]
        companies.append(company_details)
        companies_retrieved += 1

    current_page += 1

  # Create a pandas DataFrame from the list of company dictionaries
  df = pd.DataFrame(companies)
  return df


# Example usage:
state = "CA"  # Replace with the desired state abbreviation
df = get_random_companies(state, api_key, num_companies=5)

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 67
#      65 # Example usage:
#      66 state = "CA"  # Replace with the desired state abbreviation
# ---> 67 df = get_random_companies(state, api_key, num_companies=5)
#      69 print(df)
#
# Cell In[4], line 42, in get_random_companies(state, api_key, num_companies)
#      40 while companies_retrieved < len(random_indices):
#      41   params["page"] = current_page
# ---> 42   response = requests.get(search_url, params=params)
#      43   response.raise_for_status()
#      44   search_data = response.json()
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/equifax_practicum/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
# Search for active companies in the specified state
search_url = f"https://api.opencorporates.com/v0.4/companies/search"
params = {
    "q": "*",  # Search for all companies
    "jurisdiction_code": f"us_ga",
    "current_status": "Active",  # Filter for active companies
    "api_token": api_key,
    "per_page": 100  # Get maximum results per page
}
response = requests.get(search_url, params=params)
response.raise_for_status()  # Raise an exception for bad status codes
search_data = response.json()

total_companies = search_data["results"]["total_count"]

# %%
search_data
# Out:
# {'api_version': '0.4',
#  'results': {'companies': [{'company': {'name': '10X Health Franchising LLC',
#      'company_number': 'CTS-24077864',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-04-16',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-05-01T12:39:58+00:00',
#      'updated_at': '2024-09-29T13:09:33+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24077864',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '2920 NE 207th Street, 901',
#       'locality': 'Miami',
#       'region': 'FL',
#       'postal_code': '33180',
#       'country': 'United States'},
#      'registered_address_in_full': '2920 NE 207th Street, 901, Miami, FL, 33180',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': '55 Franchising, Inc.',
#      'company_number': 'CTS-18135869',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2018-11-08',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-18T23:14:41+00:00',
#      'updated_at': '2024-09-29T04:21:18+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-18135869',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'P.O. Box 8520',
#       'locality': 'S. Charleston',
#       'region': 'WV',
#       'postal_code': '25303',
#       'country': 'United States'},
#      'registered_address_in_full': 'P.O. Box 8520, S. Charleston, WV, 25303',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': '67 Ventures, Inc. dba Part Parcel',
#      'company_number': 'CTS-19082343',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2019-06-11',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T02:35:40+00:00',
#      'updated_at': '2024-09-29T02:47:08+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-19082343',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '649 Mission Street',
#       'locality': 'San Francisco',
#       'region': 'CA',
#       'postal_code': '94105',
#       'country': 'United States'},
#      'registered_address_in_full': '649 Mission Street, San Francisco, CA, 94105',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': '75 For All LLC',
#      'company_number': 'CTS-24139315',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-07-23',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-08-01T17:42:07+00:00',
#      'updated_at': '2024-09-29T13:00:53+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24139315',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '1900 Market Street, Floor 8',
#       'locality': 'Philadelphia',
#       'region': 'PA',
#       'postal_code': '19103',
#       'country': 'United States'},
#      'registered_address_in_full': '1900 Market Street, Floor 8, Philadelphia, PA, 19103',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': '76 Franchise Group LLC',
#      'company_number': 'CTS-24007040',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-01-10',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-01-21T20:24:57+00:00',
#      'updated_at': '2024-09-29T11:58:18+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24007040',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Saxton  Stump, LLC  Jarina D. Duffy, Esq., 100 Deerfield Lane, Suite 240',
#       'locality': 'Malvern',
#       'region': 'PA',
#       'postal_code': '19355',
#       'country': 'United States'},
#      'registered_address_in_full': 'Saxton  Stump, LLC  Jarina D. Duffy, Esq., 100 Deerfield Lane, Suite 240, Malvern, PA, 19355',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': '76 Franchise Group, LLC',
#      'company_number': 'CTS-24016777',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-01-24',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-02-23T09:09:32+00:00',
#      'updated_at': '2024-09-29T12:02:56+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24016777',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Saxton  Stump, LLC Jarina D. Duffy, Esq., 100 Deerfield Lane, Suite 240',
#       'locality': 'Malvern',
#       'region': 'PA',
#       'postal_code': '19355',
#       'country': 'United States'},
#      'registered_address_in_full': 'Saxton  Stump, LLC Jarina D. Duffy, Esq., 100 Deerfield Lane, Suite 240, Malvern, PA, 19355',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': "A Makers' Studio, LLC",
#      'company_number': 'CTS-18111493',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2018-09-14',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-18T22:18:31+00:00',
#      'updated_at': '2024-09-29T04:06:49+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-18111493',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '478 N Hollywood St',
#       'locality': 'Memphis',
#       'region': 'TN',
#       'postal_code': '38112',
#       'country': 'United States'},
#      'registered_address_in_full': '478 N Hollywood St, Memphis, TN, 38112',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'A1 Kitchen Bath Franchising, LLC',
#      'company_number': 'CTS-22169581',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-08-08',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2022-08-29T19:01:42+00:00',
#      'updated_at': '2024-09-29T09:56:09+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-22169581',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Fisher Zucker LLC (Attn Lane Fisher), 21 South 21st Street',
#       'locality': 'Philadelphia',
#       'region': 'PA',
#       'postal_code': '19103',
#       'country': 'United States'},
#      'registered_address_in_full': 'Fisher Zucker LLC (Attn Lane Fisher), 21 South 21st Street, Philadelphia, PA, 19103',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'AER Franchising LLC',
#      'company_number': 'CTS-21274935',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2021-10-13',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-11-17T15:05:18+00:00',
#      'updated_at': '2024-09-29T07:50:23+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-21274935',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '140 Windjammer Dr.',
#       'locality': 'Leesville',
#       'region': 'SC',
#       'postal_code': '29070',
#       'country': 'United States'},
#      'registered_address_in_full': '140 Windjammer Dr., Leesville, SC, 29070',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'ANODYNE FRANCHISING LLC',
#      'company_number': 'CTS-21246625',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2021-09-14',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T21:09:32+00:00',
#      'updated_at': '2024-09-29T07:36:39+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-21246625',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '2 Music Circle South, Ste 101',
#       'locality': 'Nashville',
#       'region': 'TN',
#       'postal_code': '37203',
#       'country': 'United States'},
#      'registered_address_in_full': '2 Music Circle South, Ste 101, Nashville, TN, 37203',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'APLGO US, LLC',
#      'company_number': 'CTS-23058689',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2023-03-13',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-04-02T20:34:10+00:00',
#      'updated_at': '2024-09-29T10:20:36+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-23058689',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '355 West 4020 North',
#       'locality': 'Provo',
#       'region': 'UT',
#       'postal_code': '84604',
#       'country': 'United States'},
#      'registered_address_in_full': '355 West 4020 North, Provo, UT, 84604',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'ASCIRA GLOBAL LLC',
#      'company_number': 'CTS-20123644',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2020-07-28',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T10:41:55+00:00',
#      'updated_at': '2024-09-29T04:21:18+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-20123644',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '16107 Kensington Drive, 418',
#       'locality': 'Sugarland',
#       'region': 'TX',
#       'postal_code': '77479',
#       'country': 'United States'},
#      'registered_address_in_full': '16107 Kensington Drive, 418, Sugarland, TX, 77479',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Able Autism Therapy Services Franchise, LLC',
#      'company_number': 'CTS-23151802',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2023-07-14',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-07-30T20:49:38+00:00',
#      'updated_at': '2024-09-29T12:00:19+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-23151802',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '6445 Shiloh Rd',
#       'locality': 'Alpharetta',
#       'region': 'GA',
#       'postal_code': '30005',
#       'country': 'United States'},
#      'registered_address_in_full': '6445 Shiloh Rd, Alpharetta, GA, 30005',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Acworth Downtown Development Authority',
#      'company_number': 'DA-17076316',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1982-04-13',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369882&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:42:59+00:00',
#      'updated_at': '2024-09-28T23:59:55+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076316',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369882&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Agravitae, Inc.',
#      'company_number': 'CTS-23236505',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2023-11-14',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-12-06T13:01:45+00:00',
#      'updated_at': '2024-09-29T12:18:45+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-23236505',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '15991 Red Hill Avenue, Suite 100',
#       'locality': 'Tustin',
#       'region': 'CA',
#       'postal_code': '92780',
#       'country': 'United States'},
#      'registered_address_in_full': '15991 Red Hill Avenue, Suite 100, Tustin, CA, 92780',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Aira Fitness Franchising LLC',
#      'company_number': 'CTS-23224717',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2023-10-27',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-11-28T20:06:09+00:00',
#      'updated_at': '2024-09-29T15:41:49+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-23224717',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '521 S. Jade Lane',
#       'locality': 'Round Lake',
#       'region': 'IL',
#       'postal_code': '60073',
#       'country': 'United States'},
#      'registered_address_in_full': '521 S. Jade Lane, Round Lake, IL, 60073',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Al-Call, Inc.',
#      'company_number': 'VF09-0006',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2009-07-30',
#      'dissolution_date': None,
#      'company_type': 'Cable/Video Franchise',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-18T13:22:53+00:00',
#      'updated_at': '2024-09-28T23:34:07+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/VF09-0006',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '405 W. 11th St.',
#       'locality': 'Alma',
#       'region': 'GA',
#       'postal_code': '31510',
#       'country': 'United States'},
#      'registered_address_in_full': '405 W. 11th St., Alma, GA, 31510',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'AlchemistX, LLC',
#      'company_number': 'CTS-24048856',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-02-27',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-03-19T19:48:58+00:00',
#      'updated_at': '2024-09-29T12:18:16+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24048856',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '602 Summerdawn Place',
#       'locality': 'Madison',
#       'region': 'AL',
#       'postal_code': '35757',
#       'country': 'United States'},
#      'registered_address_in_full': '602 Summerdawn Place, Madison, AL, 35757',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Align Your Skin, LLC',
#      'company_number': 'CTS-23060008',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2023-03-15',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-04-02T20:34:38+00:00',
#      'updated_at': '2024-09-29T14:10:46+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-23060008',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '4568 Sophia Lane',
#       'locality': 'Washington',
#       'region': 'UT',
#       'postal_code': '84780',
#       'country': 'United States'},
#      'registered_address_in_full': '4568 Sophia Lane, Washington, UT, 84780',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'An Original Company, Inc.',
#      'company_number': 'CTS-20213710',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2020-10-19',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T12:46:35+00:00',
#      'updated_at': '2024-09-29T05:33:38+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-20213710',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '21220 Devonshire Street 209',
#       'locality': 'Chatsworth',
#       'region': 'CA',
#       'postal_code': '91311',
#       'country': 'United States'},
#      'registered_address_in_full': '21220 Devonshire Street 209, Chatsworth, CA, 91311',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Annuity.com, Inc.',
#      'company_number': 'CTS-24124826',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-06-25',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-07-12T17:02:18+00:00',
#      'updated_at': '2024-09-29T13:31:59+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24124826',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '2473 S. Higley Road, Suite 104, PMB 5189',
#       'locality': 'Gilbert',
#       'region': 'AZ',
#       'postal_code': '85295',
#       'country': 'United States'},
#      'registered_address_in_full': '2473 S. Higley Road, Suite 104, PMB 5189, Gilbert, AZ, 85295',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Anovite, Inc.',
#      'company_number': 'CTS-22229456',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-10-31',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2022-11-13T07:44:27+00:00',
#      'updated_at': '2024-09-29T10:03:39+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-22229456',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '14512 South Center Point Way, Suite 100',
#       'locality': 'Bluffdale',
#       'region': 'UT',
#       'postal_code': '84065',
#       'country': 'United States'},
#      'registered_address_in_full': '14512 South Center Point Way, Suite 100, Bluffdale, UT, 84065',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'April C. White',
#      'company_number': 'FF-20010431',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2020-01-10',
#      'dissolution_date': None,
#      'company_type': 'Fiduciary - Nonresident Trustee',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T06:07:48+00:00',
#      'updated_at': '2024-09-29T03:21:31+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/FF-20010431',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Arabi Industrial Development Authority',
#      'company_number': 'DA-17076330',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2001-10-03',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369896&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:00+00:00',
#      'updated_at': '2024-09-29T00:12:52+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076330',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369896&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Argent Trust Company',
#      'company_number': 'FF-23017336',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-12-21',
#      'dissolution_date': None,
#      'company_type': 'Fiduciary - Foreign Entity Trustee',
#      'registry_url': None,
#      'branch': 'F',
#      'branch_status': 'branch of an out-of-jurisdiction company',
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-02-19T12:03:45+00:00',
#      'updated_at': '2024-09-29T10:01:03+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/FF-23017336',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '3102 West End Avenue, Suite 775',
#       'locality': 'Nashville',
#       'region': 'TN',
#       'postal_code': '37203',
#       'country': 'United States'},
#      'registered_address_in_full': '3102 West End Avenue, Suite 775, Nashville, TN, 37203',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Assist2biz, Inc.',
#      'company_number': 'CTS-18025700',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2018-02-05',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-18T18:16:11+00:00',
#      'updated_at': '2024-09-29T00:39:10+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-18025700',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'c/o Andreina  Nelson Perez, 605 Dale Ct.',
#       'locality': 'Canton',
#       'region': 'GA',
#       'postal_code': '30115',
#       'country': 'United States'},
#      'registered_address_in_full': 'c/o Andreina  Nelson Perez, 605 Dale Ct., Canton, GA, 30115',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'At Cost Metals, LLC',
#      'company_number': 'CTS-24026086',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-02-06',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-02-25T04:35:58+00:00',
#      'updated_at': '2024-09-29T13:08:16+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24026086',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '5473 Blair Rd, Suite 100',
#       'locality': 'Dallas',
#       'region': 'TX',
#       'postal_code': '75231',
#       'country': 'United States'},
#      'registered_address_in_full': '5473 Blair Rd, Suite 100, Dallas, TX, 75231',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Athens-Clarke County Downtown Development Authority',
#      'company_number': 'DA-17076335',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1995-05-17',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369901&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:00+00:00',
#      'updated_at': '2024-09-29T02:19:20+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076335',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369901&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Atkinson County-Coffee County Joint Development Authority',
#      'company_number': 'DA-17076340',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1995-03-31',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369906&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:01+00:00',
#      'updated_at': '2024-09-29T00:12:52+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076340',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369906&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Authenticus Operations, LLC',
#      'company_number': 'CTS-23058686',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2023-03-10',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2023-04-02T20:34:10+00:00',
#      'updated_at': '2024-09-29T14:10:09+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-23058686',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '6309 Guhn Road Building B',
#       'locality': 'Houston',
#       'region': 'TX',
#       'postal_code': '77040',
#       'country': 'United States'},
#      'registered_address_in_full': '6309 Guhn Road Building B, Houston, TX, 77040',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Auvoria Prime',
#      'company_number': 'CTS-22210602',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-10-05',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2022-10-18T09:48:46+00:00',
#      'updated_at': '2024-09-29T09:25:16+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-22210602',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '30 North Gould St., Suite R',
#       'locality': 'Sheridan',
#       'region': 'WY',
#       'postal_code': '82801',
#       'country': 'United States'},
#      'registered_address_in_full': '30 North Gould St., Suite R, Sheridan, WY, 82801',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BAB Ventures Franchising, LLC',
#      'company_number': 'CTS-21066147',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2021-03-15',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T16:11:39+00:00',
#      'updated_at': '2024-09-29T06:29:11+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-21066147',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '500 IDS Center, 80 South Eighth Street',
#       'locality': 'Minneapolis',
#       'region': 'MN',
#       'postal_code': '55402',
#       'country': 'United States'},
#      'registered_address_in_full': '500 IDS Center, 80 South Eighth Street, Minneapolis, MN, 55402',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BACTRONIX CORPORATION',
#      'company_number': 'CTS-20161483',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2020-08-03',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T11:44:27+00:00',
#      'updated_at': '2024-09-29T07:40:45+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-20161483',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '333 Rouser Road Bldg 4, Ste 103',
#       'locality': 'Moon Township',
#       'region': 'PA',
#       'postal_code': '15108',
#       'country': 'United States'},
#      'registered_address_in_full': '333 Rouser Road Bldg 4, Ste 103, Moon Township, PA, 15108',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BELFOR Franchise Group, LLC/PACKOUTZ International, LLC',
#      'company_number': 'CTS-21115931',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2021-04-27',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T18:00:25+00:00',
#      'updated_at': '2024-09-29T06:15:54+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-21115931',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '620 Freedom Business Center, Suite 200',
#       'locality': 'King of Prussia',
#       'region': 'PA',
#       'postal_code': '19406',
#       'country': 'United States'},
#      'registered_address_in_full': '620 Freedom Business Center, Suite 200, King of Prussia, PA, 19406',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BELFOR Franchise Group, LLC/PACKOUTZ International, LLC',
#      'company_number': 'CTS-20074797',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2020-05-19',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T08:34:47+00:00',
#      'updated_at': '2024-09-29T04:26:32+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-20074797',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '620 Freedom Business Center Suite 200',
#       'locality': 'King Prussia',
#       'region': 'PA',
#       'postal_code': '19406',
#       'country': 'United States'},
#      'registered_address_in_full': '620 Freedom Business Center Suite 200, King Prussia, PA, 19406',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BELLAME BEAUTY, INC.',
#      'company_number': 'CTS-22065005',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-03-14',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2022-04-09T22:27:58+00:00',
#      'updated_at': '2024-09-29T08:17:52+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-22065005',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '6387 Camp Bowie Blvd, Ste B 630',
#       'locality': 'Fort Worth',
#       'region': 'TX',
#       'postal_code': '76116',
#       'country': 'United States'},
#      'registered_address_in_full': '6387 Camp Bowie Blvd, Ste B 630, Fort Worth, TX, 76116',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BFB Light Franchising, LLC',
#      'company_number': 'CTS-22150690',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-06-29',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2022-07-23T17:18:10+00:00',
#      'updated_at': '2024-09-29T08:57:19+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-22150690',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Kaufman  Canoles P.C. (Nicole J. Harrell, Esq.), 150 W. Main St, Suite 1900',
#       'locality': 'Norfolk',
#       'region': 'VA',
#       'postal_code': '23510',
#       'country': 'United States'},
#      'registered_address_in_full': 'Kaufman  Canoles P.C. (Nicole J. Harrell, Esq.), 150 W. Main St, Suite 1900, Norfolk, VA, 23510',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BIGSHOTS HOLDCO, LLC',
#      'company_number': 'CTS-19011888',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2019-01-24',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T00:26:42+00:00',
#      'updated_at': '2024-09-29T02:12:19+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-19011888',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Kaufmann Gildin  Robbins LLP Attn David J. Kauffman, Esq, 767 Third Avenue',
#       'locality': 'New York',
#       'region': 'NY',
#       'postal_code': '10017',
#       'country': 'United States'},
#      'registered_address_in_full': 'Kaufmann Gildin  Robbins LLP Attn David J. Kauffman, Esq, 767 Third Avenue, New York, NY, 10017',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'BIOHM HEALTH LLC',
#      'company_number': 'CTS-19073697',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2019-05-22',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T02:20:17+00:00',
#      'updated_at': '2024-09-29T05:12:09+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-19073697',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '737 Bolivar 200',
#       'locality': 'Cleveland',
#       'region': 'OH',
#       'postal_code': '44115',
#       'country': 'United States'},
#      'registered_address_in_full': '737 Bolivar 200, Cleveland, OH, 44115',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Baker County Development Authority',
#      'company_number': 'DA-17076356',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1986-05-15',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369922&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:03+00:00',
#      'updated_at': '2024-09-28T23:59:57+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076356',
# ...
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Fisher Zucker, LLC Attn  Lane Fisher, South 21st Street',
#       'locality': 'Philadelphia',
#       'region': 'PA',
#       'postal_code': '19103',
#       'country': 'United States'},
#      'registered_address_in_full': 'Fisher Zucker, LLC Attn  Lane Fisher, South 21st Street, Philadelphia, PA, 19103',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Carol Anderson by invitation, LLC',
#      'company_number': 'CTS-22247523',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2022-11-28',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2022-12-19T23:28:09+00:00',
#      'updated_at': '2024-09-29T10:12:16+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-22247523',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'Fisher Zuker, LLC Attn Lane Fisher, 21 South 21st Street',
#       'locality': 'Philadelphia',
#       'region': 'PA',
#       'postal_code': '19103',
#       'country': 'United States'},
#      'registered_address_in_full': 'Fisher Zuker, LLC Attn Lane Fisher, 21 South 21st Street, Philadelphia, PA, 19103',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Cartersville-Bartow County Regional Industrial Development Authority',
#      'company_number': 'DA-17076424',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2004-07-27',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369990&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:07+00:00',
#      'updated_at': '2024-09-29T00:12:57+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076424',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369990&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Celljetics, LLC',
#      'company_number': 'CTS-20074805',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2020-05-21',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T08:34:47+00:00',
#      'updated_at': '2024-09-29T03:53:17+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-20074805',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '1201 Allen Drive 307',
#       'locality': 'Grand Island',
#       'region': 'NE',
#       'postal_code': '68803',
#       'country': 'United States'},
#      'registered_address_in_full': '1201 Allen Drive 307, Grand Island, NE, 68803',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Central Georgia Joint Development Authority',
#      'company_number': 'DA-17076430',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1995-12-21',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369996&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:07+00:00',
#      'updated_at': '2024-09-28T23:50:08+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076430',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369996&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Central Savannah River Area Unified Development Authority',
#      'company_number': 'DA-17076431',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1994-12-30',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369997&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:08+00:00',
#      'updated_at': '2024-09-29T02:19:25+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076431',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369997&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Cereset, LLC',
#      'company_number': 'CTS-19056558',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2019-04-12',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T01:50:56+00:00',
#      'updated_at': '2024-09-29T02:35:24+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-19056558',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '2929 N Central Ave, 21st Floor',
#       'locality': 'Phoenix',
#       'region': 'AZ',
#       'postal_code': '85012',
#       'country': 'United States'},
#      'registered_address_in_full': '2929 N Central Ave, 21st Floor, Phoenix, AZ, 85012',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'ChaChingMall, Inc.',
#      'company_number': 'CTS-18000569',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2017-11-14',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-18T17:08:19+00:00',
#      'updated_at': '2024-09-29T02:57:14+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-18000569',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '10584 Lake Seminole Terrace',
#       'locality': 'Seminole',
#       'region': 'FL',
#       'postal_code': '33772',
#       'country': 'United States'},
#      'registered_address_in_full': '10584 Lake Seminole Terrace, Seminole, FL, 33772',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Chalk Couture, LLC',
#      'company_number': 'CTS-21160965',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2021-05-19',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-19T19:12:01+00:00',
#      'updated_at': '2024-09-29T07:17:20+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-21160965',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '389 West 12800 South, Suite 510',
#       'locality': 'Draper',
#       'region': 'UT',
#       'postal_code': '84020',
#       'country': 'United States'},
#      'registered_address_in_full': '389 West 12800 South, Suite 510, Draper, UT, 84020',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Chatham County Development Authority',
#      'company_number': 'DA-17076434',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1971-06-08',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2370000&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:08+00:00',
#      'updated_at': '2024-09-28T23:50:09+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076434',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2370000&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Chicken Fingers, LLC',
#      'company_number': 'CTS-18107509',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2018-08-27',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2021-10-18T22:10:33+00:00',
#      'updated_at': '2024-09-29T01:54:48+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-18107509',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '2220 Overton Rd',
#       'locality': 'Augusta',
#       'region': 'GA',
#       'postal_code': '30904',
#       'country': 'United States'},
#      'registered_address_in_full': '2220 Overton Rd, Augusta, GA, 30904',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'Chiro Time Franchise, LLC',
#      'company_number': 'CTS-24080057',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '2024-04-19',
#      'dissolution_date': None,
#      'company_type': 'Consent to Service',
#      'registry_url': None,
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2024-05-01T12:59:38+00:00',
#      'updated_at': '2024-09-29T12:32:31+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/CTS-24080057',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': None,
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': '788 West Marietta Street, Unit 902',
#       'locality': 'Atlanta',
#       'region': 'GA',
#       'postal_code': '30318',
#       'country': 'United States'},
#      'registered_address_in_full': '788 West Marietta Street, Unit 902, Atlanta, GA, 30318',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}},
#    {'company': {'name': 'City Of Augusta Residential Care Facility For The Elderly Authority',
#      'company_number': 'DA-17076345',
#      'jurisdiction_code': 'us_ga',
#      'incorporation_date': '1981-06-02',
#      'dissolution_date': None,
#      'company_type': 'Development Authority',
#      'registry_url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369911&businessType=Development%20Authority&fromSearch=True',
#      'branch': None,
#      'branch_status': None,
#      'inactive': False,
#      'current_status': 'Active',
#      'created_at': '2017-08-22T23:43:02+00:00',
#      'updated_at': '2024-09-28T23:49:59+00:00',
#      'retrieved_at': '2024-09-25T00:00:00+00:00',
#      'opencorporates_url': 'https://opencorporates.com/companies/us_ga/DA-17076345',
#      'previous_names': [],
#      'alternative_names': [],
#      'source': {'publisher': 'Georgia Secretary of State',
#       'url': 'https://ecorp.sos.ga.gov/BusinessSearch/BusinessInformation?businessId=2369911&businessType=Development%20Authority&fromSearch=True',
#       'retrieved_at': '2024-09-25T00:00:00+00:00'},
#      'registered_address': {'street_address': 'NULL',
#       'locality': 'NULL',
#       'region': 'NULL',
#       'postal_code': 'NULL',
#       'country': 'NULL'},
#      'registered_address_in_full': 'NULL, NULL, NULL, NULL',
#      'industry_codes': [],
#      'restricted_for_marketing': None,
#      'native_company_number': None}}],
#   'page': 1,
#   'per_page': 100,
#   'total_pages': 11,
#   'total_count': 1073}}
