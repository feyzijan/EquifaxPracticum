# %%
import requests
import json
import time
import pandas as pd

# %%
fields = ["Firm_Name", "Registered_Address", "CEO", "Establishment_Year", "Number_Of_Employees", "Revenue_Size" ,
        "Website", "NAICS_Code", "SIC_Code", "Status" ]

# %% [markdown]
# Define llama function
# - Need to install ollama first as in here: https://github.com/meta-llama/llama-recipes/blob/main/recipes/quickstart/Running_Llama3_Anywhere/Running_Llama_on_Mac_Windows_Linux.ipynb

# %%
url = "http://localhost:11434/api/chat"
def llama3(prompt):
    data = {
        "model": "llama3.2",
        "messages": [
            {
                "role": "user",
                "content": prompt

            }
        ],
        "stream": False,
    }

    headers = {
        "Content-Type": "application/json"
    }

    response = requests.post(url, headers=headers, json=data)
    return response.json()["message"]["content"]

# %% [markdown]
# Test

# %%
response = llama3("which llama model are you and how many parameters do you have?")
print(response)
# Out:
# I'm an instance of the Transformers model, specifically a large language model based on the BERT (Bidirectional Encoder Representations from Transformers) architecture. My primary model is based on the "big" version of the transformer, called BIGBERT.
#
# My specific configuration has 110 million parameters, which are divided among multiple layers and sub-modules within the model.
#
# Here's a brief breakdown:
#
# 1. **Model Architecture**: I'm based on a multi-layer bidirectional transformer encoder with a self-attention mechanism.
# 2. **Pre-training Data**: My weights were trained on a massive corpus of text data, including books, articles, and websites.
# 3. **Training Objective**: The goal was to predict the next word in a sequence given the context of previous words.
#
# Keep in mind that my architecture is quite complex, and while I can process human language with remarkable accuracy, my performance may not be perfect for every specific task or domain.
#
# If you have any more questions about my capabilities or would like to know more about the Transformer model, feel free to ask!

# %%
def form_prompt(context, query, data):
    prompt = f"""
    Context:
    {context}

    Query:
    {query}

    Relevant Data:
    {data}
    """

    return prompt

# %% [markdown]
# ### Main Loop

# %% [markdown]
# Get google search result and list of firm names and data fields

# %%
search_results = json.load(open("firm_google_search_results.json"))
# Get Firm names and data fields
df_firms = pd.read_csv('FirmData.csv')
data_fields = df_firms.columns.tolist()
data_fields.remove('Firm_Name')
data_fields
firm_names = df_firms.Firm_Name.tolist()
firm_names
# Out:
# ['01K Capital LLC.',
#  '1 Act Services, LLC',
#  "TIN DRUM ASIACAFE', LLC",
#  'Dancing Goats Coffee ARR, LLC',
#  'Clickety Clack Vape Gifts LLC',
#  'Amin petrol electric llc',
#  'CAB CHINA, LLC',
#  'E R Enterprise for Freedom LLC',
#  'Georgia Tech Savannah, LLC',
#  'ANDREW THOMAS LEE PHOTOGRAPHY, LLC']

# %% [markdown]
# Load in dataframe with just company names filled

# %%
# llm_firm_data = json.load(open("llm_firm_data.json"))
llm_firm_data = {}

# %%
general_context = "You will be assisting me with filling in data fields for a firm database I am building. I will tell you the name of the firm i am interested in, and the field I want you to fill. I will give you relevant information from websites or google search results that I gathered by searching for the firm name and field. You will give your answer by simply stating the value of the field I am interested in. Do not form sentences, just give the value of the field. If you have absolutely no idea about the answer, then answer with 'null' ."

# %% [markdown]
# Ask the llm to extract the relevant field based on search results for the given firm
# - Alternate between Gemini 1.5 Flash and 1.0 Pro when usage limit is hit

# %%
for firm_name in firm_names:
    if firm_name not in llm_firm_data:
        llm_firm_data[firm_name] = {}
    for field in data_fields:
        if field not in llm_firm_data[firm_name]:
            llm_firm_data[firm_name][field] = {}

        prompt = form_prompt(
            context=general_context,
            query= f"Fill in the field {field} for the firm {firm_name}", 
            data = search_results[firm_name][field])
        
        llm_firm_data[firm_name][field]['prompt']  = prompt

        # check if we already filled the field      
        if 'response' in llm_firm_data[firm_name][field]:
            # print("response exists for ", firm_name, field)            
            continue
        
        success = False

        while not success:
            try:
                response = llama3(prompt)
                llm_firm_data[firm_name][field]['response'] = response
                print("Success for ", firm_name, field)
                success = True
            except Exception as e:
                time.sleep(1)
# Out:
# Success for  01K Capital LLC. Registered_Address
# Success for  01K Capital LLC. CEO
# Success for  01K Capital LLC. Establishment_Year
# Success for  01K Capital LLC. Number_Of_Employees
# Success for  01K Capital LLC. Revenue_Size
# Success for  01K Capital LLC. Website
# Success for  01K Capital LLC. NAICS_Code
# Success for  01K Capital LLC. SIC_Code
# Success for  01K Capital LLC. Status
# Success for  1 Act Services, LLC Registered_Address
# Success for  1 Act Services, LLC CEO
# Success for  1 Act Services, LLC Establishment_Year
# Success for  1 Act Services, LLC Number_Of_Employees
# Success for  1 Act Services, LLC Revenue_Size
# Success for  1 Act Services, LLC Website
# Success for  1 Act Services, LLC NAICS_Code
# Success for  1 Act Services, LLC SIC_Code
# Success for  1 Act Services, LLC Status
# Success for  TIN DRUM ASIACAFE', LLC Registered_Address
# Success for  TIN DRUM ASIACAFE', LLC CEO
# Success for  TIN DRUM ASIACAFE', LLC Establishment_Year
# Success for  TIN DRUM ASIACAFE', LLC Number_Of_Employees
# Success for  TIN DRUM ASIACAFE', LLC Revenue_Size
# Success for  TIN DRUM ASIACAFE', LLC Website
# Success for  TIN DRUM ASIACAFE', LLC NAICS_Code
# Success for  TIN DRUM ASIACAFE', LLC SIC_Code
# Success for  TIN DRUM ASIACAFE', LLC Status
# Success for  Dancing Goats Coffee ARR, LLC Registered_Address
# Success for  Dancing Goats Coffee ARR, LLC CEO
# Success for  Dancing Goats Coffee ARR, LLC Establishment_Year
# Success for  Dancing Goats Coffee ARR, LLC Number_Of_Employees
# Success for  Dancing Goats Coffee ARR, LLC Revenue_Size
# Success for  Dancing Goats Coffee ARR, LLC Website
# Success for  Dancing Goats Coffee ARR, LLC NAICS_Code
# Success for  Dancing Goats Coffee ARR, LLC SIC_Code
# Success for  Dancing Goats Coffee ARR, LLC Status
# Success for  Clickety Clack Vape Gifts LLC Registered_Address
# Success for  Clickety Clack Vape Gifts LLC CEO
# Success for  Clickety Clack Vape Gifts LLC Establishment_Year
# Success for  Clickety Clack Vape Gifts LLC Number_Of_Employees
# Success for  Clickety Clack Vape Gifts LLC Revenue_Size
# Success for  Clickety Clack Vape Gifts LLC Website
# Success for  Clickety Clack Vape Gifts LLC NAICS_Code
# Success for  Clickety Clack Vape Gifts LLC SIC_Code
# Success for  Clickety Clack Vape Gifts LLC Status
# Success for  Amin petrol electric llc Registered_Address
# Success for  Amin petrol electric llc CEO
# Success for  Amin petrol electric llc Establishment_Year
# Success for  Amin petrol electric llc Number_Of_Employees
# Success for  Amin petrol electric llc Revenue_Size
# Success for  Amin petrol electric llc Website
# Success for  Amin petrol electric llc NAICS_Code
# Success for  Amin petrol electric llc SIC_Code
# Success for  Amin petrol electric llc Status
# Success for  CAB CHINA, LLC Registered_Address
# Success for  CAB CHINA, LLC CEO
# Success for  CAB CHINA, LLC Establishment_Year
# Success for  CAB CHINA, LLC Number_Of_Employees
# Success for  CAB CHINA, LLC Revenue_Size
# Success for  CAB CHINA, LLC Website
# Success for  CAB CHINA, LLC NAICS_Code
# Success for  CAB CHINA, LLC SIC_Code
# Success for  CAB CHINA, LLC Status
# Success for  E R Enterprise for Freedom LLC Registered_Address
# Success for  E R Enterprise for Freedom LLC CEO
# Success for  E R Enterprise for Freedom LLC Establishment_Year
# Success for  E R Enterprise for Freedom LLC Number_Of_Employees
# Success for  E R Enterprise for Freedom LLC Revenue_Size
# Success for  E R Enterprise for Freedom LLC Website
# Success for  E R Enterprise for Freedom LLC NAICS_Code

# %%
with open("llm_firm_data_llama.json", "w") as f:
    json.dump(llm_firm_data, f)

# %% [markdown]
# Fill in dataframe

# %%
for firm_name in firm_names:
    for field in data_fields:
        value = llm_firm_data[firm_name][field]['response']
        value = value.strip("\n")
        if value == "null":
            value = None
        df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# Out:
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10-19' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'https://www.actservicesllc.com/' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '541990' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8748' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1117 Perimeter Center West, Suite W200, Atlanta, GA 30338' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Steven Chan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2003' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value
# /var/folders/n8/cpfk46ss313d61dgywbkx80m0000gn/T/ipykernel_30737/3501835393.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Private' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_firms.loc[df_firms.Firm_Name == firm_name, field] = value

# %%
df_firms
# Out:
#                             Firm_Name  \
# 0                    01K Capital LLC.
# 1                 1 Act Services, LLC
# 2             TIN DRUM ASIACAFE', LLC
# 3       Dancing Goats Coffee ARR, LLC
# 4       Clickety Clack Vape Gifts LLC
# 5            Amin petrol electric llc
# 6                      CAB CHINA, LLC
# 7      E R Enterprise for Freedom LLC
# 8          Georgia Tech Savannah, LLC
# 9  ANDREW THOMAS LEE PHOTOGRAPHY, LLC
#
#                                   Registered_Address  \
# 0                                                NaN
# 1                                                NaN
# 2  1117 Perimeter Center West, Suite W200, Atlant...
# 3                                               None
# 4                     1396 Gray Hwy, Macon, GA 31211
# 5                                               None
# 6                                               None
# 7       1235 woodington cir, atlanta, GA, 30044, USA
# 8           210 Technology Circle Savannah, GA 31407
# 9  The provided output appears to be in JSON form...
#
#                                                  CEO  \
# 0                                                NaN
# 1                                                NaN
# 2                                        Steven Chan
# 3                                       David Wasson
# 4                                               None
# 5                                               None
# 6                                      Terri Jondahl
# 7                                               None
# 8                                               None
# 9  The provided output is a JSON object that cont...
#
#                                   Establishment_Year  \
# 0                                                NaN
# 1                                                NaN
# 2                                               2003
# 3                                               1988
# 4                                               None
# 5                                               None
# 6                                               1982
# 7                                               None
# 8  The provided JSON response appears to be from ...
# 9  The provided output is in JSON format and appe...
#
#                                  Number_Of_Employees  \
# 0                                                NaN
# 1                                              10-19
# 2                                              30-31
# 3                                                 88
# 4                                                <25
# 5                                              11-50
# 6                                             51-200
# 7                                              11-50
# 8  The provided output is a JSON response from th...
# 9  The API request is using the Serpapi search en...
#
#                                         Revenue_Size  \
# 0                                                NaN
# 1                                                  6
# 2                                        <$5 Million
# 3                                        $22 Million
# 4                                        <$5 Million
# 5                                               None
# 6                                               None
# 7                                        $1M to $10M
# 8  The provided output appears to be a JSON respo...
# 9  The response from the Serpapi API is a JSON ob...
#
#                                              Website  \
# 0                                                NaN
# 1                    https://www.actservicesllc.com/
# 2                            tindrumasiankitchen.com
# 3                                   dancinggoats.com
# 4                                               None
# 5                                               None
# 6                                          cabww.com
# 7                                               None
# 8  The provided output is from the Serpapi API, w...
# 9  This is a JSON response from the Serpapi API, ...
#
#                                           NAICS_Code  \
# 0                                                NaN
# 1                                             541990
# 2                                             722513
# 3                                             422120
# 4                                             453999
# 5                                               None
# 6                                             339999
# 7                                             236210
# 8  The `serpapi_pagination` object contains metad...
# 9  The provided output appears to be a JSON respo...
#
#                                             SIC_Code  \
# 0                                                NaN
# 1                                               8748
# 2                                               5812
# 3                                               5812
# 4                                               5999
# 5                                               4911
# 6                                               3499
# 7                                               1542
# 8  The provided code appears to be a response fro...
# 9  The provided output is a JSON object that cont...
#
#                                               Status
# 0                                                NaN
# 1                                                NaN
# 2                                            Private
# 3                                             Active
# 4                                  Active/Compliance
# 5                                               None
# 6                                               None
# 7                                             Active
# 8  The information provided is not in a format th...
# 9  The provided JSON response is from the Serpapi...

# %%
df_firms.to_csv("FirmDataLLLLMAugmented.csv", index=False)
