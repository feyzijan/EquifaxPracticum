# %%
import requests
from serpapi import GoogleSearch
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[1], line 2
#
#       1 import requests
#
# ----> 2 from serpapi import GoogleSearch
#
#       3 from dotenv import load_dotenv
#
#       4 import os
#
#
#
# ModuleNotFoundError: No module named 'serpapi'

# %% [markdown]
# ### 1. Google Search API
# - doesn't work very well, irrelevant, out of date results

# %%
search_engine_id = "a4ea3a7e1261940fe"

def google_search(query, api_key):
    url = "https://www.googleapis.com/customsearch/v1"
    params = {
        "key": api_key,
        "cx": search_engine_id,
        "q": query,
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()  # Return the JSON response
    else:
        print(f"Error: {response.status_code}")
        return None

# %% [markdown]
# Example Usaeg

# %%
# Example usage
API_KEY = os.getenv("GOOGLE_SEARCH_API_KEY")
query = "Dancing Goats Coffee ARR, LLC Registered Address"
result = google_search(query, API_KEY)
print(result)
# Out:
# {'kind': 'customsearch#search', 'url': {'type': 'application/json', 'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'}, 'queries': {'request': [{'title': 'Google Custom Search - Dancing Goats Coffee ARR, LLC Registered Address', 'totalResults': '500000', 'searchTerms': 'Dancing Goats Coffee ARR, LLC Registered Address', 'count': 10, 'startIndex': 1, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'a4ea3a7e1261940fe'}], 'nextPage': [{'title': 'Google Custom Search - Dancing Goats Coffee ARR, LLC Registered Address', 'totalResults': '500000', 'searchTerms': 'Dancing Goats Coffee ARR, LLC Registered Address', 'count': 10, 'startIndex': 11, 'inputEncoding': 'utf8', 'outputEncoding': 'utf8', 'safe': 'off', 'cx': 'a4ea3a7e1261940fe'}]}, 'context': {'title': 'EquifaxDemo1'}, 'searchInformation': {'searchTime': 0.364858, 'formattedSearchTime': '0.36', 'totalResults': '500000', 'formattedTotalResults': '500,000'}, 'items': [{'kind': 'customsearch#result', 'title': 'DANCING GOATS COFFEE BAR, Decatur - Restaurant Reviews ...', 'htmlTitle': '<b>DANCING GOATS COFFEE</b> BAR, Decatur - Restaurant Reviews ...', 'link': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html', 'displayLink': 'www.tripadvisor.com', 'snippet': 'This review is the subjective opinion of a Tripadvisor member and not of Tripadvisor LLC. Tripadvisor performs checks on reviews as part of our industry-leading\xa0...', 'htmlSnippet': 'This review is the subjective opinion of a Tripadvisor member and not of Tripadvisor <b>LLC</b>. Tripadvisor performs checks on reviews as part of our industry-leading&nbsp;...', 'formattedUrl': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews...', 'htmlFormattedUrl': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews...', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrtXTQXeFJwY016EpcY0XIoiim7ug2QWHJ3eyg2ofLQmSK87mHZ_osJ-c&s', 'width': '194', 'height': '259'}], 'metatags': [{'twitter:app:url:iphone': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html?m=33762', 'apple-itunes-app': 'app-id=-1', 'og:image': 'https://media-cdn.tripadvisor.com/media/photo-p/14/18/f0/de/20180507-163126-largejpg.jpg', 'theme-color': '#34e0a1', 'og:type': 'website', 'og:image:width': '550', 'og:site_name': 'Tripadvisor', 'al:ios:app_name': 'TripAdvisor', 'twitter:app:url:ipad': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html?m=33762', 'og:title': 'DANCING GOATS COFFEE BAR, Decatur - Restaurant Reviews, Photos & Phone Number - Tripadvisor', 'twitter:app:id:ipad': '284876795', 'og:image:height': '733', 'twitter:app:id:iphone': '284876795', 'al:ios:url': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html?m=33762', 'fb:pages': '5863091683', 'og:description': 'Dancing Goats Coffee Bar, Decatur: See 102 unbiased reviews of Dancing Goats Coffee Bar, rated 4.5 of 5 on Tripadvisor and ranked #21 of 235 restaurants in Decatur.', 'al:ios:app_store_id': '284876795', 'twitter:image': 'https://media-cdn.tripadvisor.com/media/photo-p/14/18/f0/de/20180507-163126-largejpg.jpg', 'viewport': ...

# %%
result
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - Dancing Goats Coffee ARR, LLC Registered Address',
#     'totalResults': '500000',
#     'searchTerms': 'Dancing Goats Coffee ARR, LLC Registered Address',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'a4ea3a7e1261940fe'}],
#   'nextPage': [{'title': 'Google Custom Search - Dancing Goats Coffee ARR, LLC Registered Address',
#     'totalResults': '500000',
#     'searchTerms': 'Dancing Goats Coffee ARR, LLC Registered Address',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': 'a4ea3a7e1261940fe'}]},
#  'context': {'title': 'EquifaxDemo1'},
#  'searchInformation': {'searchTime': 0.364858,
#   'formattedSearchTime': '0.36',
#   'totalResults': '500000',
#   'formattedTotalResults': '500,000'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'DANCING GOATS COFFEE BAR, Decatur - Restaurant Reviews ...',
#    'htmlTitle': '<b>DANCING GOATS COFFEE</b> BAR, Decatur - Restaurant Reviews ...',
#    'link': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html',
#    'displayLink': 'www.tripadvisor.com',
#    'snippet': 'This review is the subjective opinion of a Tripadvisor member and not of Tripadvisor LLC. Tripadvisor performs checks on reviews as part of our industry-leading\xa0...',
#    'htmlSnippet': 'This review is the subjective opinion of a Tripadvisor member and not of Tripadvisor <b>LLC</b>. Tripadvisor performs checks on reviews as part of our industry-leading&nbsp;...',
#    'formattedUrl': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews...',
#    'htmlFormattedUrl': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrtXTQXeFJwY016EpcY0XIoiim7ug2QWHJ3eyg2ofLQmSK87mHZ_osJ-c&s',
#       'width': '194',
#       'height': '259'}],
#     'metatags': [{'twitter:app:url:iphone': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html?m=33762',
#       'apple-itunes-app': 'app-id=-1',
#       'og:image': 'https://media-cdn.tripadvisor.com/media/photo-p/14/18/f0/de/20180507-163126-largejpg.jpg',
#       'theme-color': '#34e0a1',
#       'og:type': 'website',
#       'og:image:width': '550',
#       'og:site_name': 'Tripadvisor',
#       'al:ios:app_name': 'TripAdvisor',
#       'twitter:app:url:ipad': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html?m=33762',
#       'og:title': 'DANCING GOATS COFFEE BAR, Decatur - Restaurant Reviews, Photos & Phone Number - Tripadvisor',
#       'twitter:app:id:ipad': '284876795',
#       'og:image:height': '733',
#       'twitter:app:id:iphone': '284876795',
#       'al:ios:url': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html?m=33762',
#       'fb:pages': '5863091683',
#       'og:description': 'Dancing Goats Coffee Bar, Decatur: See 102 unbiased reviews of Dancing Goats Coffee Bar, rated 4.5 of 5 on Tripadvisor and ranked #21 of 235 restaurants in Decatur.',
#       'al:ios:app_store_id': '284876795',
#       'twitter:image': 'https://media-cdn.tripadvisor.com/media/photo-p/14/18/f0/de/20180507-163126-largejpg.jpg',
#       'viewport': 'width=device-width, initial-scale=1.0, viewport-fit=cover',
#       'og:locale': 'en-US',
#       'og:url': 'https://www.tripadvisor.com/Restaurant_Review-g34895-d873323-Reviews-Dancing_Goats_Coffee_Bar-Decatur_Georgia.html',
#       'format-detection': 'telephone=no'}],
#     'cse_image': [{'src': 'https://media-cdn.tripadvisor.com/media/photo-p/14/18/f0/de/20180507-163126-largejpg.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': "Kaldi's Coffee: Kaldi's Coffee - Specialty Coffee Roaster, St. Louis, MO",
#    'htmlTitle': 'Kaldi&#39;s <b>Coffee</b>: Kaldi&#39;s <b>Coffee</b> - Specialty <b>Coffee</b> Roaster, St. Louis, MO',
#    'link': 'https://kaldiscoffee.com/',
#    'displayLink': 'kaldiscoffee.com',
#    'snippet': "Kaldi's Coffee is dedicated to creating a memorable coffee experience for customers and guests via sustainable practices and education. We have cafes in St.",
#    'htmlSnippet': 'Kaldi&#39;s <b>Coffee</b> is dedicated to creating a memorable <b>coffee</b> experience for customers and guests via sustainable practices and education. We have cafes in St.',
#    'formattedUrl': 'https://kaldiscoffee.com/',
#    'htmlFormattedUrl': 'https://kaldis<b>coffee</b>.com/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSlv1khsizwqnQv2TyPKGADKS0BB38szQMY3aPydf2-bJRAa2JIGg1cvlk&s',
#       'width': '311',
#       'height': '162'}],
#     'organization': [{'logo': 'https://kaldiscoffee.com/cdn/shop/files/KaldisLogo_PrimaryNavy-01_490x.png?v=1701701196',
#       'url': 'https://kaldiscoffee.com/'}],
#     'metatags': [{'og:image': 'https://cdn.shopify.com/s/files/1/0187/0338/files/KaldisLogo_PrimaryNavy-01.png?height=628&pad_color=ffffff&v=1701701196&width=1200',
#       'theme-color': '#003349',
#       'og:type': 'website',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Kaldi’s Coffee - Specialty Coffee Roaster, St. Louis, MO',
#       'og:image:width': '1200',
#       'og:site_name': "Kaldi's Coffee",
#       'og:title': 'Kaldi’s Coffee - Specialty Coffee Roaster, St. Louis, MO',
#       'shopify-checkout-api-token': '9f7162d77bff6dc55cd7b45592e168f7',
#       'og:image:height': '628',
#       'og:description': 'Kaldi’s Coffee is dedicated to creating a memorable coffee experience for customers and guests via sustainable practices and education. We have cafes in St. Louis, MO, and Atlanta, GA.',
#       'og:image:secure_url': 'https://cdn.shopify.com/s/files/1/0187/0338/files/KaldisLogo_PrimaryNavy-01.png?height=628&pad_color=ffffff&v=1701701196&width=1200',
#       'viewport': 'width=device-width, initial-scale=1.0, height=device-height, minimum-scale=1.0, user-scalable=0',
#       'twitter:description': 'Kaldi’s Coffee is dedicated to creating a memorable coffee experience for customers and guests via sustainable practices and education. We have cafes in St. Louis, MO, and Atlanta, GA.',
#       'shopify-digital-wallet': '/1870338/digital_wallets/dialog',
#       'og:url': 'https://kaldiscoffee.com/'}],
#     'cse_image': [{'src': 'https://cdn.shopify.com/s/files/1/0187/0338/files/KaldisLogo_PrimaryNavy-01.png?height=628&pad_color=ffffff&v=1701701196&width=1200'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'DANCING GOATS, Atlanta - Restaurant Reviews, Photos & Phone ...',
#    'htmlTitle': '<b>DANCING GOATS</b>, Atlanta - Restaurant Reviews, Photos &amp; <b>Phone</b> ...',
#    'link': 'https://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Reviews-Dancing_Goats-Atlanta_Georgia.html',
#    'displayLink': 'www.tripadvisor.com',
#    'snippet': 'Have visited several times after shopping at Ponce City Market and to meet business associates. The coffee is very good. The price point not very different from\xa0...',
#    'htmlSnippet': 'Have visited several times after shopping at Ponce City Market and to meet <b>business</b> associates. The <b>coffee</b> is very good. The price point not very different from&nbsp;...',
#    'formattedUrl': 'https://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Revie...',
#    'htmlFormattedUrl': 'https://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Revie...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQdX80plUBdToM_ZxpDao_FKnbB_IFdabCfUDk8uE84xhg9wP930gUmYIA&s',
#       'width': '224',
#       'height': '224'}],
#     'metatags': [{'twitter:app:url:iphone': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Reviews-Dancing_Goats-Atlanta_Georgia.html?m=33762',
#       'apple-itunes-app': 'app-id=284876795, app-argument=https://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Reviews-Dancing_Goats-Atlanta_Georgia.html',
#       'og:image': 'https://media-cdn.tripadvisor.com/media/photo-p/11/e3/70/d9/photo0jpg.jpg',
#       'theme-color': '#34e0a1',
#       'og:type': 'website',
#       'og:image:width': '550',
#       'og:site_name': 'Tripadvisor',
#       'al:ios:app_name': 'TripAdvisor',
#       'twitter:app:url:ipad': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Reviews-Dancing_Goats-Atlanta_Georgia.html?m=33762',
#       'og:title': 'DANCING GOATS, Atlanta - Restaurant Reviews, Photos & Phone Number - Tripadvisor',
#       'twitter:app:id:ipad': '284876795',
#       'og:image:height': '550',
#       'twitter:app:id:iphone': '284876795',
#       'al:ios:url': 'tripadvisor://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Reviews-Dancing_Goats-Atlanta_Georgia.html?m=33762',
#       'fb:pages': '5863091683',
#       'og:description': 'Dancing Goats, Atlanta: See 24 unbiased reviews of Dancing Goats, rated 4.5 of 5 on Tripadvisor and ranked #713 of 2,294 restaurants in Atlanta.',
#       'al:ios:app_store_id': '284876795',
#       'twitter:image': 'https://media-cdn.tripadvisor.com/media/photo-p/11/e3/70/d9/photo0jpg.jpg',
#       'viewport': 'width=device-width, initial-scale=1.0, viewport-fit=cover',
#       'og:locale': 'en-US',
#       'og:url': 'https://www.tripadvisor.com/Restaurant_Review-g60898-d7806965-Reviews-Dancing_Goats-Atlanta_Georgia.html',
#       'format-detection': 'telephone=no'}],
#     'cse_image': [{'src': 'https://media-cdn.tripadvisor.com/media/photo-p/11/e3/70/d9/photo0jpg.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Community Invited to Attend Thurston Green Business Awards with ...',
#    'htmlTitle': 'Community Invited to Attend Thurston Green <b>Business</b> Awards with ...',
#    'link': 'https://thurstongreenbusiness.com/community-invited-to-attend-thurston-green-business-awards-with-keynote-by-aaron-sauerhoff-ceo-and-founder-of-earth-homes/',
#    'displayLink': 'thurstongreenbusiness.com',
#    'snippet': 'Mar 29, 2023 ... ... address by Aaron Sauerhoff, CEO and Founder of Earth Homes LLC. ... Dancing Goats® Coffee Earth Homes LLC ECOS Enlightenment Home Care\xa0...',
#    'htmlSnippet': 'Mar 29, 2023 <b>...</b> ... <b>address</b> by Aaron Sauerhoff, CEO and Founder of Earth Homes <b>LLC</b>. ... <b>Dancing Goats</b>® <b>Coffee</b> Earth Homes <b>LLC</b> ECOS Enlightenment Home Care&nbsp;...',
#    'formattedUrl': 'https://thurstongreenbusiness.com/community-invited-to-attend-thurston-gr...',
#    'htmlFormattedUrl': 'https://thurstongreenbusiness.com/community-invited-to-attend-thurston-gr...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTS-Uu0Clfe6D3Wbj3F6hTalPofLgii5AO3gPdbN5aB6zG_k7v9J9YDg3Y&s',
#       'width': '184',
#       'height': '273'}],
#     'metatags': [{'og:image': 'https://thurstongreenbusiness.com/wp-content/uploads/2023/03/Screen-Shot-2023-03-29-at-4.49.37-PM.png',
#       'og:type': 'article',
#       'article:published_time': '2023-03-29T23:50:06+00:00',
#       'og:image:width': '467',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Thurston Green Business',
#       'author': 'Natasha Ashenhurst',
#       'og:title': 'Community Invited to Attend Thurston Green Business Awards with Keynote by Aaron Sauerhoff, CEO and Founder of Earth Homes - Thurston Green Business',
#       'og:image:height': '691',
#       'twitter:label1': 'Written by',
#       'twitter:label2': 'Est. reading time',
#       'og:image:type': 'image/png',
#       'msapplication-tileimage': 'https://thurstongreenbusiness.com/wp-content/uploads/2016/08/cropped-green_business_logo_newcolors@05x-270x270.png',
#       'og:description': 'Get ready to be inspired and join us in celebrating the cream of the crop at the Thurston Green Designation ceremony! Over 100 businesses went above and beyond this year to earn the prestigious designation, and we can’t wait to honor them at the Chamber’s April Forum on Wednesday, April 12 at 11:00 am at […]',
#       'twitter:data1': 'Natasha Ashenhurst',
#       'twitter:data2': '3 minutes',
#       'article:modified_time': '2023-03-29T23:52:57+00:00',
#       'viewport': 'width=device-width, initial-scale=1',
#       'og:locale': 'en_US',
#       'og:url': 'https://thurstongreenbusiness.com/community-invited-to-attend-thurston-green-business-awards-with-keynote-by-aaron-sauerhoff-ceo-and-founder-of-earth-homes/'}],
#     'cse_image': [{'src': 'https://thurstongreenbusiness.com/wp-content/uploads/2023/03/Screen-Shot-2023-03-29-at-4.49.37-PM.png'}],
#     'hatomfeed': [{}]}},
#   {'kind': 'customsearch#result',
#    'title': 'West Egg Cafe',
#    'htmlTitle': 'West Egg <b>Cafe</b>',
#    'link': 'https://www.westeggcafe.com/',
#    'displayLink': 'www.westeggcafe.com',
#    'snippet': 'NEWS. View fullsize. Dancing Goats Coffee (previously known as Batdorf & Bronson) ... Email Address *. Phone Number *, Ext. Company. Select your desired event\xa0...',
#    'htmlSnippet': 'NEWS. View fullsize. <b>Dancing Goats Coffee</b> (previously known as Batdorf &amp; Bronson) ... Email <b>Address</b> *. <b>Phone Number</b> *, Ext. Company. Select your desired event&nbsp;...',
#    'formattedUrl': 'https://www.westeggcafe.com/',
#    'htmlFormattedUrl': 'https://www.westeggcafe.com/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRon0X7K-pGVWu4b_UX3-6xdp4qIUos872Ky4EogHJ0cbpIYBo8IpvivRHS&s',
#       'width': '363',
#       'height': '139'}],
#     'metatags': [{'og:image': 'http://static1.squarespace.com/static/5e73c79ca17bc64d1c68d4a5/t/5e73c7c87419624820066428/1584646090206/WestEgglogopng.png?format=1500w',
#       'og:type': 'website',
#       'og:image:width': '1500',
#       'twitter:title': 'West Egg Cafe',
#       'twitter:card': 'summary',
#       'og:site_name': 'West Egg Cafe',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:url': 'https://www.westeggcafe.com',
#       'og:title': 'West Egg Cafe',
#       'og:image:height': '574',
#       'og:url': 'https://www.westeggcafe.com',
#       'twitter:image': 'http://static1.squarespace.com/static/5e73c79ca17bc64d1c68d4a5/t/5e73c7c87419624820066428/1584646090206/WestEgglogopng.png?format=1500w'}],
#     'cse_image': [{'src': 'http://static1.squarespace.com/static/5e73c79ca17bc64d1c68d4a5/t/5e73c7c87419624820066428/1584646090206/WestEgglogopng.png?format=1500w'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Work – St. Clair Superior',
#    'htmlTitle': 'Work – St. Clair Superior',
#    'link': 'https://www.stclairsuperior.org/work/',
#    'displayLink': 'www.stclairsuperior.org',
#    'snippet': 'Name Abol The Dancing Goat Coffee House, Address 6125 Saint Clair Ave, Phone 1-216-391-9400 ; Name Abranovich, Edward & Reeves, Josephine, Address 6918 Saint\xa0...',
#    'htmlSnippet': 'Name Abol The <b>Dancing Goat Coffee</b> House, <b>Address</b> 6125 Saint Clair Ave, Phone 1-216-391-9400 ; Name Abranovich, Edward &amp; Reeves, Josephine, <b>Address</b> 6918 Saint&nbsp;...',
#    'formattedUrl': 'https://www.stclairsuperior.org/work/',
#    'htmlFormattedUrl': 'https://www.stclairsuperior.org/work/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT4Oc9gX_TULEKNJon6UVNG9-f0kqGE8p3VriNCpa2s9c3FENCi73wPFtA&s',
#       'width': '372',
#       'height': '135'}],
#     'imageobject': [{'image': 'https://www.stclairsuperior.org/wp-content/uploads/2019/10/logo_horizontal_main3.png',
#       'url': 'https://www.stclairsuperior.org/'},
#      {'image': 'https://www.stclairsuperior.org/wp-content/uploads/bb-plugin/cache/Skidmark7-square-e0bb8ee9c070f4fc4e9375f199fab6ef-61b29cd4f1881.jpg'},
#      {'image': 'https://www.stclairsuperior.org/wp-content/uploads/bb-plugin/cache/upcycle_st._clair_thrive_photo-landscape-c30a8e73338437e7cd6e36ba7b4e273a-61b29cd4f18bd.jpg'},
#      {'image': 'https://www.stclairsuperior.org/wp-content/uploads/bb-plugin/cache/DSC_6334-landscape-aa950085f4efb313ddb9be0857c04cec-61b29cd4f18c0.jpg'},
#      {'image': 'https://www.stclairsuperior.org/wp-content/uploads/bb-plugin/cache/festival_food-landscape-9b37613ec16809fdf4502a24e046d43e-61b29cd4f18c3.jpg'},
#      {'image': 'https://www.stclairsuperior.org/wp-content/uploads/bb-plugin/cache/SCS-x-AA_NOV-2021-1-square-af14af1d53d576c9d4ca792df36e7c42-61b29cd4f1956.jpg'},
#      {'image': 'https://www.stclairsuperior.org/wp-content/uploads/2019/11/logo_vertical_stack_white.png'}],
#     'organization': [{'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://www.instagram.com/stclairsuperior'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://www.facebook.com/stclairsuperior'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://www.instagram.com/stclairsuperior'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://www.facebook.com/stclairsuperior'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://visitor.constantcontact.com/manage/optin?v=001pRmNkNNhb39mrY230GFd-cNjQYnZ9AOLfn5MtJVXNY0U0IvIqjViZtUYcIm0-XroSas_q6tWdA1IL2JZ4Tfq6GEfp5oNFSgi'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://www.instagram.com/stclairsuperior'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://www.facebook.com/stclairsuperior'},
#      {'url': 'https://www.stclairsuperior.org/',
#       'sameas': 'https://visitor.constantcontact.com/manage/optin?v=001pRmNkNNhb39mrY230GFd-cNjQYnZ9AOLfn5MtJVXNY0U0IvIqjViZtUYcIm0-XroSas_q6tWdA1IL2JZ4Tfq6GEfp5oNFSgi'}],
#     'metatags': [{'viewport': 'width=device-width, initial-scale=1.0',
#       'tec-api-origin': 'https://www.stclairsuperior.org',
#       'msapplication-tileimage': 'https://www.stclairsuperior.org/wp-content/uploads/2021/11/cropped-Favicon_1-270x270.png',
#       'tec-api-version': 'v1'}],
#     'webpage': [{'maincontentofpage': "Work in St. Clair Superior we are HARD AT WORK St. Clair Superior is home to dozens of small businesses, nonprofits, restaurants, art studios, and manufacturers. Together we're working to make..."}],
#     'creativework': [{'name': 'Restaurants',
#       'description': 'Restaurants',
#       'text': "Work in St. Clair Superior we are HARD AT WORK St. Clair Superior is home to dozens of small businesses, nonprofits, restaurants, art studios, and manufacturers. Together we're working to make..."}],
#     'cse_image': [{'src': 'https://www.stclairsuperior.org/wp-content/uploads/2019/10/logo_horizontal_main3.png'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Dancing Goats Coffee | Creative Loafing',
#    'htmlTitle': '<b>Dancing Goats Coffee</b> | Creative Loafing',
#    'link': 'https://creativeloafing.com/business-545-dancing-goats-coffee',
#    'displayLink': 'creativeloafing.com',
#    'snippet': 'Dec 8, 2015 ... The first Ponce City Market business to open within the renovated City Hall East complex, Dancing Goats is a community coffee bar operated\xa0...',
#    'htmlSnippet': 'Dec 8, 2015 <b>...</b> The first Ponce City Market <b>business</b> to open within the renovated City Hall East complex, <b>Dancing Goats</b> is a community <b>coffee</b> bar operated&nbsp;...',
#    'formattedUrl': 'https://creativeloafing.com/business-545-dancing-goats-coffee',
#    'htmlFormattedUrl': 'https://creativeloafing.com/business-545-<b>dancing</b>-<b>goats</b>-<b>coffee</b>',
#    'pagemap': {'offer': [{'pricecurrency': 'USD',
#       'price': '0.00',
#       'url': 'http://www.batdorfcoffee.com/'}],
#     'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcShoBeDRBnCvjoVhprLaTE2GN7XDkRCxO3uFbNUgK4NcIgaA8AaDJN9GSA&s',
#       'width': '225',
#       'height': '225'}],
#     'organization': [{'name': 'Dancing Goats Coffee',
#       'url': 'https://creativeloafing.com/business-545-dancing-goats-coffee'}],
#     'postaladdress': [{'addresslocality': 'Atlanta',
#       'postalcode': '30308',
#       'addressregion': 'GA',
#       'streetaddress': '650 North Ave. N.E.'}],
#     'metatags': [{'application-name': 'Creative Loafing',
#       'msapplication-tilecolor': '#0000ff',
#       'og:image': 'https://creativeloafing.com/themes/CreativeLoafing/img/CreativeLoafing_logo_1020.png',
#       'msapplication-config': 'themes/CreativeLoafing/favicons/browserconfig.xml?v=dLmNjEzW8X',
#       'twitter:title': 'Dancing Goats Coffee | Creative Loafing',
#       'og:type': 'website',
#       'twitter:card': 'summary',
#       'theme-color': '#ffffff',
#       'og:image:width': '1020',
#       'og:image:alt': 'CREATIVE LOAFING LOGO',
#       'og:site_name': 'Creative Loafing',
#       'twitter:domain': 'https://creativeloafing.com/',
#       'msvalidate.01': '7BB1BE5341DC2C7CB2338C4BA0C3DEFB',
#       'og:title': 'Dancing Goats Coffee | Creative Loafing',
#       'apple-mobile-web-app-title': 'Creative Loafing',
#       'og:image:height': '1020',
#       'og:description': 'The first Ponce City Market business to open within the renovated City Hall East complex, Dancing Goats is a community coffee bar operated by Batdorf & Bronson Coffee Roasters. \n\n \nThe Old Fourth Ward location features an airy covered patio, a full-service coffee bar, locally made doughnuts and pastries, and a small selection of sandwiches.',
#       'twitter:image': 'https://creativeloafing.com/themes/CreativeLoafing/img/CreativeLoafing_logo_1020.png',
#       'fb:app_id': '791405044921262',
#       'twitter:site': 'Creative Loafing',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': 'The first Ponce City Market business to open within the renovated City Hall East complex, Dancing Goats is a community coffee bar operated by Batdorf & Bronson Coffee Roasters. \n\n \nThe Old Fourth Ward location features an airy covered patio, a full-service coffee bar, locally made doughnuts and pastries, and a small selection of sandwiches.',
#       'og:url': 'https://creativeloafing.com/business-545-dancing-goats-coffee'}],
#     'place': [{'address': 'Atlanta, GA',
#       'name': 'Dancing Goats Coffee',
#       'url': 'https://creativeloafing.com/business-545-dancing-goats-coffee'}],
#     'cse_image': [{'src': 'https://creativeloafing.com/themes/CreativeLoafing/img/CreativeLoafing_logo_1020.png'}],
#     'event': [{'enddate': 'Wed Dec 9 00:00:00 2015T00:00:00+0000',
#       'eventattendancemode': 'https://schema.org/OfflineEventAttendanceMode',
#       'name': 'Coffee and Camp',
#       'description': 'How to find the right Jewish overnight camp for your child. Stop by and get information, guidance, find out about discounts and scholarships, free brochures and giveaways [click here for more]',
#       'startdate': 'Wed Dec 9 00:00:00 2015T00:00:00+0000',
#       'url': 'Coffee and Camp'}],
#     'localbusiness': [{'image': 'https://dev.creativeloafing.com/image/2014/07/640w/1a4b0_dancing_goats_coffee_bar_magnum.jpg',
#       'openinghours': 'Hours Monday: 6:30 AM – 7:00 PM Tuesday: 6:30 AM – 7:00 PM Wednesday: 6:30 AM – 7:00 PM Thursday: 6:30 AM – 7:00 PM Friday: 6:30 AM – 7:00 PM Saturday: 7:00 AM – 7:00 PM Sunday:...',
#       'name': 'Dancing Goats Coffee',
#       'description': 'The first Ponce City Market business to open within the renovated City Hall East complex, Dancing Goats is a community coffee bar operated by Batdorf & Bronson Coffee Roasters. The Old Fourth...',
#       'telephone': '(404) 874-0370',
#       'url': 'batdorfcoffee.com'}],
#     'geocoordinates': [{'latitude': '33.7714194',
#       'longitude': '-84.3673833'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'Approved Vendors - The Chehalis Tribe',
#    'htmlTitle': 'Approved Vendors - The Chehalis Tribe',
#    'link': 'https://www.chehalistribe.org/departments/planning-department/approved-vendors/',
#    'displayLink': 'www.chehalistribe.org',
#    'snippet': "Sep 24, 2018 ... Dancing Goats Coffee; D'Arcy Basil Art; David Pickernell, Ted ... Dutch Bros, LLC Dba Dutch Bros Coffee; Eagle Asphalt Seal Coating Co\xa0...",
#    'htmlSnippet': 'Sep 24, 2018 <b>...</b> <b>Dancing Goats Coffee</b>; D&#39;Arcy Basil <b>Art</b>; David Pickernell, Ted ... Dutch Bros, <b>LLC</b> Dba Dutch Bros <b>Coffee</b>; Eagle Asphalt Seal Coating Co&nbsp;...',
#    'formattedUrl': 'https://www.chehalistribe.org/departments/planning.../approved-vendors/',
#    'htmlFormattedUrl': 'https://www.chehalistribe.org/departments/planning.../approved-vendors/',
#    'pagemap': {'metatags': [{'og:type': 'article',
#       'article:published_time': '2018-09-24T22:06:14+00:00',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'The Chehalis Tribe',
#       'tec-api-origin': 'https://www.chehalistribe.org',
#       'og:title': 'Approved Vendors - The Chehalis Tribe',
#       'twitter:label1': 'Written by',
#       'et-api-origin': 'https://www.chehalistribe.org',
#       'msapplication-tileimage': 'https://www.chehalistribe.org/wp-content/uploads/2018/09/eagle-logo.png',
#       'og:description': 'Before You Begin Hiring The following companies have applied for and received a business license through the Chehalis Tribal Planning Department. The list below is updated monthly. We maintain the list below in alphabetical order. You can scroll through the list or use the search box to query the list.',
#       'twitter:data1': 'admin',
#       'article:modified_time': '2023-09-28T20:46:32+00:00',
#       'viewport': 'width=device-width,initial-scale=1',
#       'og:locale': 'en_US',
#       'et-api-version': 'v1',
#       'og:url': 'https://www.chehalistribe.org/departments/planning-department/approved-vendors/',
#       'tec-api-version': 'v1'}],
#     'hatomfeed': [{}]}},
#   {'kind': 'customsearch#result',
#    'title': 'The General Muir',
#    'htmlTitle': 'The General Muir',
#    'link': 'https://www.thegeneralmuir.com/',
#    'displayLink': 'www.thegeneralmuir.com',
#    'snippet': "... Dancing Goats coffee as well as a full bar of wine, beer, spirits, and cocktails. Next door to The General Muir at Emory Point, you'll find TGM Bread and\xa0...",
#    'htmlSnippet': '... <b>Dancing Goats coffee</b> as well as a full bar of wine, beer, spirits, and cocktails. Next door to The General Muir at Emory Point, you&#39;ll find TGM Bread and&nbsp;...',
#    'formattedUrl': 'https://www.thegeneralmuir.com/',
#    'htmlFormattedUrl': 'https://www.thegeneralmuir.com/',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWA_0wAJ107a_wMJUtcL9-tnWbW-DgwY_3AbBjXTUEOI5kxptxbn3fFe9t&s',
#       'width': '284',
#       'height': '177'}],
#     'metatags': [{'og:image': 'http://static1.squarespace.com/static/5e74ed686297ba58291c7268/t/6012e1e5dc997f7652f1342c/1611850217278/tgm_logo_tile-01.png?format=1500w',
#       'og:type': 'website',
#       'og:image:width': '1200',
#       'twitter:title': 'The General Muir',
#       'twitter:card': 'summary',
#       'og:site_name': 'The General Muir',
#       'twitter:url': 'https://www.thegeneralmuir.com',
#       'og:title': 'The General Muir',
#       'og:image:height': '750',
#       'og:description': 'The General Muir is a modern American restaurant inspired by classic New York Jewish deli, returning it to its hand-crafted roots. Traditional favorites are honored — pastrami is cured and smoked in house, bagels are hand rolled and kettle boiled — and joined by dishes going beyond tradition, focusi',
#       'twitter:image': 'http://static1.squarespace.com/static/5e74ed686297ba58291c7268/t/6012e1e5dc997f7652f1342c/1611850217278/tgm_logo_tile-01.png?format=1500w',
#       'viewport': 'width=device-width, initial-scale=1',
#       'twitter:description': 'The General Muir is a modern American restaurant inspired by classic New York Jewish deli, returning it to its hand-crafted roots. Traditional favorites are honored — pastrami is cured and smoked in house, bagels are hand rolled and kettle boiled — and joined by dishes going beyond tradition, focusi',
#       'og:url': 'https://www.thegeneralmuir.com'}],
#     'cse_image': [{'src': 'http://static1.squarespace.com/static/5e74ed686297ba58291c7268/t/6012e1e5dc997f7652f1342c/1611850217278/tgm_logo_tile-01.png?format=1500w'}]}},
#   {'kind': 'customsearch#result',
#    'title': '2023 Farmers Market Vendors | Lebanon, NH',
#    'htmlTitle': '2023 Farmers Market Vendors | Lebanon, NH',
#    'link': 'https://lebanonnh.gov/1498/Market-Vendors',
#    'displayLink': 'lebanonnh.gov',
#    'snippet': 'Sweet Doe Gelato - Premium Farmstead Goat Milk Gelato; Hato Viejo Coffee - locally roasted whole bean and ground coffee; iced coffee; Cedar Circle Farm and\xa0...',
#    'htmlSnippet': 'Sweet Doe Gelato - Premium Farmstead <b>Goat</b> Milk Gelato; Hato Viejo <b>Coffee</b> - locally roasted whole bean and ground <b>coffee</b>; iced <b>coffee</b>; Cedar Circle Farm and&nbsp;...',
#    'formattedUrl': 'https://lebanonnh.gov/1498/Market-Vendors',
#    'htmlFormattedUrl': 'https://lebanonnh.gov/1498/Market-Vendors',
#    'pagemap': {'metatags': [{'category2': 'Departments',
#       'category3': 'Recreation, Arts, and Parks',
#       'category4': "Farmers' Market",
#       'theme-color': '#365d8d',
#       'category5': 'Market Vendors',
#       'viewport': 'width=device-width, initial-scale=1',
#       'category0': 'Home',
#       'category1': 'Your Government'}]}}]}

# %% [markdown]
# # 2. Serp API
# - works very well but is paid after 100 search/month
# - below code built the search dataset for the 10 firms we have

# %%
params = {
  "api_key": os.getenv("SERP_API_KEY"),
  "engine": "google",
  "q": "INSERT QUERY HERE",
  "location": "United States",
  "google_domain": "google.com",
  "gl": "us",
  "hl": "en",
  "safe": "active"
}

# Ger list of firms and columns
df_firms = pd.read_csv('FirmData.csv')
data_fields = df_firms.columns.tolist()
data_fields.remove('Firm_Name')
firm_names = df_firms.Firm_Name.tolist()

# get results for all firms
search_results = {}
for firm in firm_names:
    search_results[firm] = {}
    for field in data_fields:
        field_to_search = field.replace('_', ' ')
        params['q'] = f"{firm} {field_to_search}"
        search = GoogleSearch(params)
        search_results[firm][field] =  search.get_dict()

# save results
with open("firm_google_search_results.json", "w") as f:
    json.dump(search_results, f)

a = json.load(open("firm_google_search_results.json"))
a[firm_names[2]][data_fields[2]]
