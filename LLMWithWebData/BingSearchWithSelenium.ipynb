# %%
import requests
from dotenv import load_dotenv
import os
load_dotenv()


from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# %% [markdown]
# Set parameters

# %%
class BingSearchAPI():

    def __init__(self) -> None:

        # replace with list of keys once i run out
        self.subscription_key_free  = os.getenv("BING_SEARCH_API_KEY_FREE_1")
        self.subscription_key_paid = os.getenv("BING_SEARCH_API_KEY_PAID_1")
        self.headers = {"Ocp-Apim-Subscription-Key": self.subscription_key_free}             
            
        self.search_url = "https://api.bing.microsoft.com/v7.0/search"

        self.params = {
            "q": "Inser Query here",
            "count": 20,  # Number of search results to return
            "offset": 0,  # The offset for pagination
            "mkt": "en-US",  # Region
            "safesearch": "Moderate"  # Safe search filter
        }

        self.search_results = {}
        self.webpages = {}

    def search(self, query: str) -> dict:
        self.params["q"] = query
        response = requests.get(self.search_url, headers=self.headers, params=self.params)

        try:
            response.raise_for_status()
        except requests.exceptions.HTTPError as e:
            print(f"Request failed: {e}")
            return "Bing Search has failed"
        
        self.search_results = response.json()

        # get dict of site names and urls
        for result in self.search_results['webPages']['value']:
            print("Result is ", result)
            print(result["siteName"])
            self.webpages[result["siteName"]] = result["url"]
    
        return self.search_results
    
    def get_top_webpages(self) -> list:
        return self.webpages

# %%
class WebScraper():
    def __init__(self) -> None:
        # Set up Chrome driver with webdriver manager
        self.options = webdriver.ChromeOptions()
        self.options.add_argument('--headless')  # Run headless for no browser window
        self.options.add_argument('--disable-gpu')  # Disable GPU acceleration
        self.options.add_argument('--no-sandbox')  # Required for some Linux environments

        # Automatically download and use ChromeDriver
        self.driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=self.options)

        # for using requests
        self.requests_headers =  {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        }

    def extract_text_with_selenium(self,url):
        try:
            # Open the URL in the browser
            self.driver.get(url)
            # Let the page load
            time.sleep(2) 
            # Get page source and parse it after it has fully loaded
            page_source = self.driver.page_source
            soup = BeautifulSoup(page_source, 'html.parser')
            text = soup.get_text(separator='\n')
            return text
        except Exception as e:
            print(f"An error occurred: {e}")
            return "No content"
        
    def extract_text_with_requests(self,url):
        try:
            # Fetch the content from the URL with headers
            response = requests.get(url, headers=self.requests_headers)
            response.raise_for_status()  # Check if the request was successful

            # Parse text
            soup = BeautifulSoup(response.text, 'html.parser')
            text = soup.get_text(separator='\n')  # Using '\n' to preserve some structure
            return text
        except Exception as e:
            print(f"Error fetching the URL: {e}")
            return "No content"
        
    def scrape_webpage(self, url: str) -> str:
        # use both methods and return the one that works
        text_1 = self.extract_text_with_selenium(url)
        text_2 = self.extract_text_with_requests(url)

        if len(text_1) > len(text_2):
            return text_1
        else:
            return text_2

# %%
bing_searcher = BingSearchAPI()
site_scraper = WebScraper()

# %% [markdown]
# Test for one web page

# %%
r = bing_searcher.search("Dancing Goats Coffee ARR, LLC Registered Address")
urls = bing_searcher.get_top_webpages()
urls
# Out:
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.0', 'name': 'DANCING GOATS COFFEE ARR, LLC - Bizapedia', 'url': 'https://www.bizapedia.com/ga/dancing-goats-coffee-arr-llc.html', 'datePublished': '2024-08-16T00:00:00.0000000', 'datePublishedDisplayText': 'Aug 16, 2024', 'isFamilyFriendly': True, 'displayUrl': 'https://www.bizapedia.com/ga/dancing-goats-coffee-arr-llc.html', 'snippet': "DANCING GOATS COFFEE ARR, LLC. DANCING GOATS COFFEE ARR, LLC is a Georgia Domestic Limited-Liability Company filed on July 5, 2022. The company's filing status is listed as Active/Compliance and its File Number is 22146246. The Registered Agent on file for this company is Bob J Goldberg and is located at 1600 Parkwood Circle Suite 400, Atlanta ...", 'dateLastCrawled': '2024-09-27T18:07:00.0000000Z', 'language': 'en', 'isNavigational': True, 'richFacts': [{'label': {'text': 'Location'}, 'items': [{'text': 'WA'}], 'hint': {'text': 'ADDRESS:LOCATIONGENERAL'}}], 'noCache': False, 'siteName': 'Bizapedia'}
# Bizapedia
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.1', 'name': 'Dancing Goats Coffee ARR, LLC :: Georgia (US) - OpenCorporates', 'url': 'https://opencorporates.com/companies/us_ga/22146246', 'isFamilyFriendly': True, 'displayUrl': 'https://opencorporates.com/companies/us_ga/22146246', 'snippet': 'Dancing Goats Coffee ARR, LLC Company Number 22146246 Status Active/Compliance Incorporation Date 5 July 2022 (6 months ago) Company Type Domestic Limited Liability Company Jurisdiction Georgia (US) Registered Address. 200 Market Street, N.E. Olympia; 98501; WA; United States; Agent Name Bob J Goldberg Agent Address Atlanta, GA, 30339, United ...', 'dateLastCrawled': '2023-01-12T00:05:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'OpenCorporates'}
# OpenCorporates
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.2', 'name': 'Dancing Goats Coffee ARR, LLC | Georgia Company Directory', 'url': 'https://www.georgiacompanyregistry.com/companies/dancing-goats-coffee-arr-llc/', 'isFamilyFriendly': True, 'displayUrl': 'https://www.georgiacompanyregistry.com/companies/dancing-goats-coffee-arr-llc', 'snippet': "Dancing Goats Coffee ARR, LLC was registered on Jul 05 2022 as a domestic limited liability company type with the address 200 Market St. NE, Olympia, WA, 98501, USA. The company id for this entity is 22146246. The agent name for this entity is: Bob J Goldberg. The entity's status is Active now.", 'dateLastCrawled': '2024-08-22T19:55:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Georgia Company Directory'}
# Georgia Company Directory
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.3', 'name': 'DANCING GOATS COFFEE ARR, LLC - Dun & Bradstreet', 'url': 'https://www.dnb.com/business-directory/company-profiles.dancing_goats_coffee_arr_llc.5289ecb2821a112e00d439ea81257e48.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dnb.com/business-directory/company-profiles.dancing_goats_coffee_arr_llc...', 'snippet': 'Find company research, competitor information, contact details & financial data for DANCING GOATS COFFEE ARR, LLC of Olympia, WA. Get the latest business insights from Dun & Bradstreet. DANCING GOATS COFFEE ARR, LLC. ... / DANCING GOATS COFFEE ARR, LLC; DANCING GOATS COFFEE ARR, LLC. Website. Get a D&B Hoovers Free Trial.', 'dateLastCrawled': '2024-03-31T01:49:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dun & Bradstreet'}
# Dun & Bradstreet
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.4', 'name': 'Bob Goldberg | Phone Number | DANCING GOATS COFFEE ARR, LLC | Principal', 'url': 'https://www.dnb.com/contact-directory/contact-profile.bob_goldberg.bae2e7c3aa2a9186195de3c8265b35c6.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.bob_goldberg.bae2e7c3aa2a9186195...', 'snippet': 'View the business profile and contact info for Bob Goldberg, Principal at DANCING GOATS COFFEE ARR, LLC in Washington, US. Dynamic search and list-building capabilities; Real-time trigger alerts; Comprehensive company profiles; Valuable research and technology reports; Get a D&B Hoovers Free Trial.', 'dateLastCrawled': '2024-09-30T05:03:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dun & Bradstreet'}
# Dun & Bradstreet
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.5', 'name': 'Julia Koffee | Email Address | Phone Number | DANCING GOATS COFFEE ARR ...', 'url': 'https://www.dnb.com/contact-directory/contact-profile.julia.2e483e852e97e19a803477836675b5fe.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.julia.2e483e852e97e19a...', 'snippet': 'View the business profile and contact info for Julia Koffee, Sales And Outreach Coordinator at DANCING GOATS COFFEE ARR, LLC in Washington, US Dynamic search and list-building capabilities Real-time trigger alerts', 'dateLastCrawled': '2024-10-02T08:06:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dun & Bradstreet'}
# Dun & Bradstreet
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.6', 'name': 'Atlanta, GA - Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/atlanta-cafes', 'thumbnailUrl': 'https://www.bing.com/th?id=OIP.y6LvXjRJpyDuBsTSNn2DOwHaFj&w=80&h=80&c=1&pid=5.1', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/atlanta-cafes', 'snippet': 'Dancing Goats® Ponce city market. 650 North Ave. NE Atlanta, GA 30308 (404) 874-0370 Hours: Mon-Fri: 6:30AM to 7PM | Sat-Sun: 7AM to 7PM Off the Beltline and with plenty of bicycle parking, our coffee bar is a local favorite stopover for people visiting festivals, concerts, parks, or just shopping at Ponce City Market. order online.', 'dateLastCrawled': '2024-10-09T00:12:00.0000000Z', 'primaryImageOfPage': {'thumbnailUrl': 'https://www.bing.com/th?id=OIP.y6LvXjRJpyDuBsTSNn2DOwHaFj&w=80&h=80&c=1&pid=5.1', 'width': 80, 'height': 80, 'sourceWidth': 474, 'sourceHeight': 355, 'imageId': 'OIP.y6LvXjRJpyDuBsTSNn2DOwHaFj'}, 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.7', 'name': 'Online Menu of Dancing Goats Coffee Bar, Atlanta, GA', 'url': 'https://www.menupix.com/atlanta/restaurants/31628996/Dancing-Goats-Coffee-Bar-Atlanta-GA', 'isFamilyFriendly': True, 'displayUrl': 'https://www.menupix.com/atlanta/restaurants/31628996/Dancing-Goats-Coffee-Bar-Atlanta-GA', 'snippet': 'View the menu for Dancing Goats Coffee Bar and restaurants in Atlanta, GA. See restaurant menus, reviews, ratings, phone number, address, hours, photos and maps.', 'dateLastCrawled': '2024-01-29T06:39:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'MenuPix'}
# MenuPix
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.8', 'name': 'Dancing Goats® Buckhead | Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/the-dancing-goats-coffee-bar-buckhead', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/the-dancing-goats-coffee-bar-buckhead', 'snippet': 'Dancing Goats® Buckhead. 3167 Peachtree Rd Atlanta, GA 30305 (404) 343-2064. Map This Location. Hours: Mon-Fri: 6:30am to 7pm Sat-Sun: 7am to 7pm. Opened in the Spring of 2018, Dancing Goats ® Coffee Bar @ The Exchange is located in the heart of Buckhead. Convenient to local shopping and restaurants, this location boasts a modern design and ...', 'dateLastCrawled': '2024-10-05T15:36:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.9', 'name': 'Dancing Goats® Decatur | Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/dancing-goats-coffee-bar', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/dancing-goats-coffee-bar', 'snippet': 'Dancing Goats® Decatur. 419 W. Ponce De Leon Decatur, GA 30030 (404) 687-1100. Map This Location. Hours: Mon-Fri: 6:30am to 7pm Sat-Sun: 7am to 7pm. Dancing Goats ® Decatur, situated in the greater Atlanta metro area, opened in the fall of 2007. This store offers exceptional espresso beverages, locally-made doughnuts and a manual brew bar ...', 'dateLastCrawled': '2024-10-03T04:02:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.10', 'name': 'Dancing Goats Coffee Arr, LLC in Olympia, WA - (360) 753-3391', 'url': 'https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391', 'isFamilyFriendly': True, 'displayUrl': 'https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391', 'snippet': 'Dancing Goats Coffee Arr, LLC is in the Coffee Shop business. View competitors, revenue, employees, website and phone number.', 'dateLastCrawled': '2023-04-05T06:39:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Buzzfile'}
# Buzzfile
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.11', 'name': 'Brendan Smith | Phone Number | DANCING GOATS COFFEE ARR, LLC | Eastern ...', 'url': 'https://www.dnb.com/contact-directory/contact-profile.brendan_smith.123f0a783ae96e913af82e998765af48.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.brendan_smith.123f0a783ae96e913...', 'snippet': 'View the business profile and contact info for Brendan Smith, Eastern Retail Operations Manager at DANCING GOATS COFFEE ARR, LLC in Washington, US Dynamic search and list-building capabilities Real-time trigger alerts', 'dateLastCrawled': '2024-09-30T05:03:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dun & Bradstreet'}
# Dun & Bradstreet
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.12', 'name': 'Customer FAQ - Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/customer-faq', 'datePublished': '2021-05-24T00:00:00.0000000', 'datePublishedDisplayText': 'May 24, 2021', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/customer-faq', 'snippet': 'Customer FAQ | Dancing Goats® Coffee. Customer FAQ. Our customer service team is here to answer your questions Monday-Thursday from 7:00AM to 5:00PM and Friday 10AM to 5:00PM PST. If you have a question, send us E-Mail or call 1-800-955-5282 ext. 138. We will respond to your inquiry within 24 hours, or the following business day if you ...', 'dateLastCrawled': '2024-10-01T06:20:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.13', 'name': 'DANCING GOATS COFFEE COMPANY :: Pennsylvania (US) - OpenCorporates', 'url': 'https://opencorporates.com/companies/us_pa/2639070', 'isFamilyFriendly': True, 'displayUrl': 'https://opencorporates.com/companies/us_pa/2639070', 'snippet': 'Free and open company data on Pennsylvania (US) company DANCING GOATS COFFEE COMPANY (company number 2639070), 5830 ELLSWORTH AVE STE 100, PITTSBURGH, PA, 15232 Changes to our website — to find out why access to some data now requires a login, click here', 'dateLastCrawled': '2024-05-10T13:36:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'OpenCorporates'}
# OpenCorporates
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.14', 'name': 'Jennifer Dalmy | Email Address | Phone Number | DANCING GOATS COFFEE ...', 'url': 'https://www.dnb.com/contact-directory/contact-profile.jennifer_dalmy.d966ead4ea872573d4c94e579e895593.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.jennifer_dalmy.d966ead4ea872573d...', 'snippet': 'View the business profile and contact info for Jennifer Dalmy, Regional Sales Manager at DANCING GOATS COFFEE ARR, LLC in Washington, US Dynamic search and list-building capabilities Real-time trigger alerts', 'dateLastCrawled': '2024-09-28T09:29:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dun & Bradstreet'}
# Dun & Bradstreet
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.15', 'name': 'Customer Service - Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/customer-service', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/customer-service', 'snippet': 'Customer Support Our customer service team is here to answer your questions Monday-Thursday from 7:00AM to 5:00PM and Friday 10AM to 5:00PM PST. If you have a question, send us E-Mail or call 1-800-955-5282 ext. 138. We will respond to your inquiry within 24 hours, or the following business day if you contacted us on a', 'dateLastCrawled': '2024-10-04T04:16:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.16', 'name': '200 MARKET ST NE OLYMPIA, WA 98501-6965 - Bizapedia', 'url': 'https://www.bizapedia.com/addresses/200-market-st-ne-olympia-wa-98501.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.bizapedia.com/addresses/200-market-st-ne-olympia-wa-98501.html', 'snippet': 'There are 9 companies that have an address matching 200 Market St Ne Olympia, WA 98501-6965. The companies are Challain Inc Spc, Challain Inc, Dgcb Atl Ponce City Market LLC, Dgcb Atl 33 Peachtree Place LLC, Dgcb Atl Buckhead Exchange LLC, Tdgcb LLC, Challain Inc, Dancing Goats Coffee Arr LLC, and Dancing Goats Coffee.', 'dateLastCrawled': '2024-08-24T12:53:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Bizapedia'}
# Bizapedia
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.17', 'name': 'Contact Us - Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/contact-us', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/contact-us', 'snippet': 'Dancing Goats ® Coffee 200 Market St. NE Olympia, WA 98501. Call: 800.955.JAVA (5282) MON-FRI: 9AM to 5PM PST. Email: info@dancinggoats.com or use the form on this page: Customer Support. Our customer service team is here to answer your questions MON-THUR from 9AM to 5PM PST. If you have a question, send us an e-mail or call 1-800-955-5282 ext ...', 'dateLastCrawled': '2024-10-05T06:54:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.18', 'name': 'Wholesale | Dancing Goats® Coffee', 'url': 'https://www.dancinggoats.com/pages/wholesale-info', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dancinggoats.com/pages/wholesale-info', 'snippet': 'Contact (800) 955-5282. info@dancinggoats.com. Facebook; Twitter; Instagram; YouTube; Free standard shipping on orders over $60 | All others just $5* Shop. ... and ends when a Dancing Goats® Coffee trained and certified barista crafts and serves coffee to a waiting customer.', 'dateLastCrawled': '2024-10-08T09:37:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dancing Goats® Coffee'}
# Dancing Goats® Coffee
# Result is  {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.19', 'name': 'Zoe McKay | DANCING GOATS COFFEE ARR, LLC | Shift Lead - Dun & Bradstreet', 'url': 'https://www.dnb.com/contact-directory/contact-profile.zoe.cb802a4479b3264f89a76231ec17f223.html', 'isFamilyFriendly': True, 'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.zoe.cb802a4479b3264f89a76231ec17...', 'snippet': 'View the business profile and contact info for Zoe McKay, Shift Lead at DANCING GOATS COFFEE ARR, LLC in Washington, US. Dynamic search and list-building capabilities; Real-time trigger alerts; Comprehensive company profiles; Valuable research and technology reports; Get a D&B Hoovers Free Trial.', 'dateLastCrawled': '2024-10-02T12:45:00.0000000Z', 'language': 'en', 'isNavigational': False, 'noCache': False, 'siteName': 'Dun & Bradstreet'}
# Dun & Bradstreet
# {'Bizapedia': 'https://www.bizapedia.com/addresses/200-market-st-ne-olympia-wa-98501.html',
#  'OpenCorporates': 'https://opencorporates.com/companies/us_pa/2639070',
#  'Georgia Company Directory': 'https://www.georgiacompanyregistry.com/companies/dancing-goats-coffee-arr-llc/',
#  'Dun & Bradstreet': 'https://www.dnb.com/contact-directory/contact-profile.zoe.cb802a4479b3264f89a76231ec17f223.html',
#  'Dancing Goats® Coffee': 'https://www.dancinggoats.com/pages/wholesale-info',
#  'MenuPix': 'https://www.menupix.com/atlanta/restaurants/31628996/Dancing-Goats-Coffee-Bar-Atlanta-GA',
#  'Buzzfile': 'https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391'}

# %%
r
# Out:
# {'_type': 'SearchResponse',
#  'queryContext': {'originalQuery': 'Dancing Goats Coffee ARR, LLC Registered Address',
#   'askUserForLocation': True},
#  'webPages': {'webSearchUrl': 'https://www.bing.com/search?q=Dancing+Goats+Coffee+ARR%2c+LLC+Registered+Address',
#   'totalEstimatedMatches': 147000,
#   'value': [{'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.0',
#     'name': 'DANCING GOATS COFFEE ARR, LLC - Bizapedia',
#     'url': 'https://www.bizapedia.com/ga/dancing-goats-coffee-arr-llc.html',
#     'datePublished': '2024-08-16T00:00:00.0000000',
#     'datePublishedDisplayText': 'Aug 16, 2024',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.bizapedia.com/ga/dancing-goats-coffee-arr-llc.html',
#     'snippet': "DANCING GOATS COFFEE ARR, LLC. DANCING GOATS COFFEE ARR, LLC is a Georgia Domestic Limited-Liability Company filed on July 5, 2022. The company's filing status is listed as Active/Compliance and its File Number is 22146246. The Registered Agent on file for this company is Bob J Goldberg and is located at 1600 Parkwood Circle Suite 400, Atlanta ...",
#     'dateLastCrawled': '2024-09-27T18:07:00.0000000Z',
#     'language': 'en',
#     'isNavigational': True,
#     'richFacts': [{'label': {'text': 'Location'},
#       'items': [{'text': 'WA'}],
#       'hint': {'text': 'ADDRESS:LOCATIONGENERAL'}}],
#     'noCache': False,
#     'siteName': 'Bizapedia'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.1',
#     'name': 'Dancing Goats Coffee ARR, LLC :: Georgia (US) - OpenCorporates',
#     'url': 'https://opencorporates.com/companies/us_ga/22146246',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://opencorporates.com/companies/us_ga/22146246',
#     'snippet': 'Dancing Goats Coffee ARR, LLC Company Number 22146246 Status Active/Compliance Incorporation Date 5 July 2022 (6 months ago) Company Type Domestic Limited Liability Company Jurisdiction Georgia (US) Registered Address. 200 Market Street, N.E. Olympia; 98501; WA; United States; Agent Name Bob J Goldberg Agent Address Atlanta, GA, 30339, United ...',
#     'dateLastCrawled': '2023-01-12T00:05:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'OpenCorporates'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.2',
#     'name': 'Dancing Goats Coffee ARR, LLC | Georgia Company Directory',
#     'url': 'https://www.georgiacompanyregistry.com/companies/dancing-goats-coffee-arr-llc/',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.georgiacompanyregistry.com/companies/dancing-goats-coffee-arr-llc',
#     'snippet': "Dancing Goats Coffee ARR, LLC was registered on Jul 05 2022 as a domestic limited liability company type with the address 200 Market St. NE, Olympia, WA, 98501, USA. The company id for this entity is 22146246. The agent name for this entity is: Bob J Goldberg. The entity's status is Active now.",
#     'dateLastCrawled': '2024-08-22T19:55:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Georgia Company Directory'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.3',
#     'name': 'DANCING GOATS COFFEE ARR, LLC - Dun & Bradstreet',
#     'url': 'https://www.dnb.com/business-directory/company-profiles.dancing_goats_coffee_arr_llc.5289ecb2821a112e00d439ea81257e48.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dnb.com/business-directory/company-profiles.dancing_goats_coffee_arr_llc...',
#     'snippet': 'Find company research, competitor information, contact details & financial data for DANCING GOATS COFFEE ARR, LLC of Olympia, WA. Get the latest business insights from Dun & Bradstreet. DANCING GOATS COFFEE ARR, LLC. ... / DANCING GOATS COFFEE ARR, LLC; DANCING GOATS COFFEE ARR, LLC. Website. Get a D&B Hoovers Free Trial.',
#     'dateLastCrawled': '2024-03-31T01:49:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dun & Bradstreet'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.4',
#     'name': 'Bob Goldberg | Phone Number | DANCING GOATS COFFEE ARR, LLC | Principal',
#     'url': 'https://www.dnb.com/contact-directory/contact-profile.bob_goldberg.bae2e7c3aa2a9186195de3c8265b35c6.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.bob_goldberg.bae2e7c3aa2a9186195...',
#     'snippet': 'View the business profile and contact info for Bob Goldberg, Principal at DANCING GOATS COFFEE ARR, LLC in Washington, US. Dynamic search and list-building capabilities; Real-time trigger alerts; Comprehensive company profiles; Valuable research and technology reports; Get a D&B Hoovers Free Trial.',
#     'dateLastCrawled': '2024-09-30T05:03:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dun & Bradstreet'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.5',
#     'name': 'Julia Koffee | Email Address | Phone Number | DANCING GOATS COFFEE ARR ...',
#     'url': 'https://www.dnb.com/contact-directory/contact-profile.julia.2e483e852e97e19a803477836675b5fe.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.julia.2e483e852e97e19a...',
#     'snippet': 'View the business profile and contact info for Julia Koffee, Sales And Outreach Coordinator at DANCING GOATS COFFEE ARR, LLC in Washington, US Dynamic search and list-building capabilities Real-time trigger alerts',
#     'dateLastCrawled': '2024-10-02T08:06:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dun & Bradstreet'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.6',
#     'name': 'Atlanta, GA - Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/atlanta-cafes',
#     'thumbnailUrl': 'https://www.bing.com/th?id=OIP.y6LvXjRJpyDuBsTSNn2DOwHaFj&w=80&h=80&c=1&pid=5.1',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/atlanta-cafes',
#     'snippet': 'Dancing Goats® Ponce city market. 650 North Ave. NE Atlanta, GA 30308 (404) 874-0370 Hours: Mon-Fri: 6:30AM to 7PM | Sat-Sun: 7AM to 7PM Off the Beltline and with plenty of bicycle parking, our coffee bar is a local favorite stopover for people visiting festivals, concerts, parks, or just shopping at Ponce City Market. order online.',
#     'dateLastCrawled': '2024-10-09T00:12:00.0000000Z',
#     'primaryImageOfPage': {'thumbnailUrl': 'https://www.bing.com/th?id=OIP.y6LvXjRJpyDuBsTSNn2DOwHaFj&w=80&h=80&c=1&pid=5.1',
#      'width': 80,
#      'height': 80,
#      'sourceWidth': 474,
#      'sourceHeight': 355,
#      'imageId': 'OIP.y6LvXjRJpyDuBsTSNn2DOwHaFj'},
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.7',
#     'name': 'Online Menu of Dancing Goats Coffee Bar, Atlanta, GA',
#     'url': 'https://www.menupix.com/atlanta/restaurants/31628996/Dancing-Goats-Coffee-Bar-Atlanta-GA',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.menupix.com/atlanta/restaurants/31628996/Dancing-Goats-Coffee-Bar-Atlanta-GA',
#     'snippet': 'View the menu for Dancing Goats Coffee Bar and restaurants in Atlanta, GA. See restaurant menus, reviews, ratings, phone number, address, hours, photos and maps.',
#     'dateLastCrawled': '2024-01-29T06:39:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'MenuPix'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.8',
#     'name': 'Dancing Goats® Buckhead | Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/the-dancing-goats-coffee-bar-buckhead',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/the-dancing-goats-coffee-bar-buckhead',
#     'snippet': 'Dancing Goats® Buckhead. 3167 Peachtree Rd Atlanta, GA 30305 (404) 343-2064. Map This Location. Hours: Mon-Fri: 6:30am to 7pm Sat-Sun: 7am to 7pm. Opened in the Spring of 2018, Dancing Goats ® Coffee Bar @ The Exchange is located in the heart of Buckhead. Convenient to local shopping and restaurants, this location boasts a modern design and ...',
#     'dateLastCrawled': '2024-10-05T15:36:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.9',
#     'name': 'Dancing Goats® Decatur | Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/dancing-goats-coffee-bar',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/dancing-goats-coffee-bar',
#     'snippet': 'Dancing Goats® Decatur. 419 W. Ponce De Leon Decatur, GA 30030 (404) 687-1100. Map This Location. Hours: Mon-Fri: 6:30am to 7pm Sat-Sun: 7am to 7pm. Dancing Goats ® Decatur, situated in the greater Atlanta metro area, opened in the fall of 2007. This store offers exceptional espresso beverages, locally-made doughnuts and a manual brew bar ...',
#     'dateLastCrawled': '2024-10-03T04:02:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.10',
#     'name': 'Dancing Goats Coffee Arr, LLC in Olympia, WA - (360) 753-3391',
#     'url': 'https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391',
#     'snippet': 'Dancing Goats Coffee Arr, LLC is in the Coffee Shop business. View competitors, revenue, employees, website and phone number.',
#     'dateLastCrawled': '2023-04-05T06:39:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Buzzfile'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.11',
#     'name': 'Brendan Smith | Phone Number | DANCING GOATS COFFEE ARR, LLC | Eastern ...',
#     'url': 'https://www.dnb.com/contact-directory/contact-profile.brendan_smith.123f0a783ae96e913af82e998765af48.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.brendan_smith.123f0a783ae96e913...',
#     'snippet': 'View the business profile and contact info for Brendan Smith, Eastern Retail Operations Manager at DANCING GOATS COFFEE ARR, LLC in Washington, US Dynamic search and list-building capabilities Real-time trigger alerts',
#     'dateLastCrawled': '2024-09-30T05:03:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dun & Bradstreet'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.12',
#     'name': 'Customer FAQ - Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/customer-faq',
#     'datePublished': '2021-05-24T00:00:00.0000000',
#     'datePublishedDisplayText': 'May 24, 2021',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/customer-faq',
#     'snippet': 'Customer FAQ | Dancing Goats® Coffee. Customer FAQ. Our customer service team is here to answer your questions Monday-Thursday from 7:00AM to 5:00PM and Friday 10AM to 5:00PM PST. If you have a question, send us E-Mail or call 1-800-955-5282 ext. 138. We will respond to your inquiry within 24 hours, or the following business day if you ...',
#     'dateLastCrawled': '2024-10-01T06:20:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.13',
#     'name': 'DANCING GOATS COFFEE COMPANY :: Pennsylvania (US) - OpenCorporates',
#     'url': 'https://opencorporates.com/companies/us_pa/2639070',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://opencorporates.com/companies/us_pa/2639070',
#     'snippet': 'Free and open company data on Pennsylvania (US) company DANCING GOATS COFFEE COMPANY (company number 2639070), 5830 ELLSWORTH AVE STE 100, PITTSBURGH, PA, 15232 Changes to our website — to find out why access to some data now requires a login, click here',
#     'dateLastCrawled': '2024-05-10T13:36:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'OpenCorporates'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.14',
#     'name': 'Jennifer Dalmy | Email Address | Phone Number | DANCING GOATS COFFEE ...',
#     'url': 'https://www.dnb.com/contact-directory/contact-profile.jennifer_dalmy.d966ead4ea872573d4c94e579e895593.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.jennifer_dalmy.d966ead4ea872573d...',
#     'snippet': 'View the business profile and contact info for Jennifer Dalmy, Regional Sales Manager at DANCING GOATS COFFEE ARR, LLC in Washington, US Dynamic search and list-building capabilities Real-time trigger alerts',
#     'dateLastCrawled': '2024-09-28T09:29:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dun & Bradstreet'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.15',
#     'name': 'Customer Service - Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/customer-service',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/customer-service',
#     'snippet': 'Customer Support Our customer service team is here to answer your questions Monday-Thursday from 7:00AM to 5:00PM and Friday 10AM to 5:00PM PST. If you have a question, send us E-Mail or call 1-800-955-5282 ext. 138. We will respond to your inquiry within 24 hours, or the following business day if you contacted us on a',
#     'dateLastCrawled': '2024-10-04T04:16:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.16',
#     'name': '200 MARKET ST NE OLYMPIA, WA 98501-6965 - Bizapedia',
#     'url': 'https://www.bizapedia.com/addresses/200-market-st-ne-olympia-wa-98501.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.bizapedia.com/addresses/200-market-st-ne-olympia-wa-98501.html',
#     'snippet': 'There are 9 companies that have an address matching 200 Market St Ne Olympia, WA 98501-6965. The companies are Challain Inc Spc, Challain Inc, Dgcb Atl Ponce City Market LLC, Dgcb Atl 33 Peachtree Place LLC, Dgcb Atl Buckhead Exchange LLC, Tdgcb LLC, Challain Inc, Dancing Goats Coffee Arr LLC, and Dancing Goats Coffee.',
#     'dateLastCrawled': '2024-08-24T12:53:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Bizapedia'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.17',
#     'name': 'Contact Us - Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/contact-us',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/contact-us',
#     'snippet': 'Dancing Goats ® Coffee 200 Market St. NE Olympia, WA 98501. Call: 800.955.JAVA (5282) MON-FRI: 9AM to 5PM PST. Email: info@dancinggoats.com or use the form on this page: Customer Support. Our customer service team is here to answer your questions MON-THUR from 9AM to 5PM PST. If you have a question, send us an e-mail or call 1-800-955-5282 ext ...',
#     'dateLastCrawled': '2024-10-05T06:54:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.18',
#     'name': 'Wholesale | Dancing Goats® Coffee',
#     'url': 'https://www.dancinggoats.com/pages/wholesale-info',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dancinggoats.com/pages/wholesale-info',
#     'snippet': 'Contact (800) 955-5282. info@dancinggoats.com. Facebook; Twitter; Instagram; YouTube; Free standard shipping on orders over $60 | All others just $5* Shop. ... and ends when a Dancing Goats® Coffee trained and certified barista crafts and serves coffee to a waiting customer.',
#     'dateLastCrawled': '2024-10-08T09:37:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dancing Goats® Coffee'},
#    {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.19',
#     'name': 'Zoe McKay | DANCING GOATS COFFEE ARR, LLC | Shift Lead - Dun & Bradstreet',
#     'url': 'https://www.dnb.com/contact-directory/contact-profile.zoe.cb802a4479b3264f89a76231ec17f223.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.dnb.com/contact-directory/contact-profile.zoe.cb802a4479b3264f89a76231ec17...',
#     'snippet': 'View the business profile and contact info for Zoe McKay, Shift Lead at DANCING GOATS COFFEE ARR, LLC in Washington, US. Dynamic search and list-building capabilities; Real-time trigger alerts; Comprehensive company profiles; Valuable research and technology reports; Get a D&B Hoovers Free Trial.',
#     'dateLastCrawled': '2024-10-02T12:45:00.0000000Z',
#     'language': 'en',
#     'isNavigational': False,
#     'noCache': False,
#     'siteName': 'Dun & Bradstreet'}]},
#  'places': {'value': [{'_type': 'Restaurant',
#     'id': 'https://api.bing.microsoft.com/api/v7/#Places.0',
#     'webSearchUrl': 'https://www.bing.com/entityexplore?q=Dancing+Goats+Coffee&filters=local_ypid:%22YN873x17927439471315774259%22&elv=AXXfrEiqqD9r3GuelwApulo0yQBvlWmiSDFuzbR1VfWxCeTcTGywG0HfmgdJmstn3gM9FLZvdaqLBdHZidtXrfK3lr1T1WF20HhWdHcesENX',
#     'name': 'Dancing Goats Coffee',
#     'url': 'https://www.dancinggoats.com/pages/locations',
#     'entityPresentationInfo': {'entityScenario': 'ListItem',
#      'entityTypeHints': ['Place', 'LocalBusiness', 'Restaurant']},
#     'address': {'addressLocality': 'Atlanta',
#      'addressRegion': 'GA',
#      'postalCode': '30309',
#      'addressCountry': 'US',
#      'neighborhood': ''},
#     'telephone': '(404) 600-6547'},
#    {'_type': 'Restaurant',
#     'id': 'https://api.bing.microsoft.com/api/v7/#Places.1',
#     'webSearchUrl': 'https://www.bing.com/entityexplore?q=Dancing+Goats&filters=local_ypid:%22YN873x113265148%22&elv=AXXfrEiqqD9r3GuelwApulo0yQBvlWmiSDFuzbR1VfWxCeTcTGywG0HfmgdJmstn3gM9FLZvdaqLBdHZidtXrfK3lr1T1WF20HhWdHcesENX',
#     'name': 'Dancing Goats',
#     'url': 'https://www.dancinggoats.com/',
#     'entityPresentationInfo': {'entityScenario': 'ListItem',
#      'entityTypeHints': ['Place', 'LocalBusiness', 'Restaurant']},
#     'address': {'addressLocality': 'Atlanta',
#      'addressRegion': 'GA',
#      'postalCode': '30308',
#      'addressCountry': 'US',
#      'neighborhood': 'Old Fourth Ward'},
#     'telephone': '(404) 874-0370'},
#    {'_type': 'Restaurant',
#     'id': 'https://api.bing.microsoft.com/api/v7/#Places.2',
#     'webSearchUrl': 'https://www.bing.com/entityexplore?q=Dancing+Goats+Coffee&filters=local_ypid:%22YN873x14671124182212730555%22&elv=AXXfrEiqqD9r3GuelwApulo0yQBvlWmiSDFuzbR1VfWxCeTcTGywG0HfmgdJmstn3gM9FLZvdaqLBdHZidtXrfK3lr1T1WF20HhWdHcesENX',
#     'name': 'Dancing Goats Coffee',
#     'url': 'https://www.dancinggoats.com/pages/atlanta-cafes',
#     'entityPresentationInfo': {'entityScenario': 'ListItem',
#      'entityTypeHints': ['Place', 'LocalBusiness', 'Restaurant']},
#     'address': {'addressLocality': 'Atlanta',
#      'addressRegion': 'GA',
#      'postalCode': '30305',
#      'addressCountry': 'US',
#      'neighborhood': ''},
#     'telephone': '(404) 343-2064'},
#    {'_type': 'Restaurant',
#     'id': 'https://api.bing.microsoft.com/api/v7/#Places.3',
#     'webSearchUrl': 'https://www.bing.com/entityexplore?q=Dancing+Goats+Coffee+Emory&filters=local_ypid:%22YN873x3690036753023033656%22&elv=AXXfrEiqqD9r3GuelwApulo0yQBvlWmiSDFuzbR1VfWxCeTcTGywG0HfmgdJmstn3gM9FLZvdaqLBdHZidtXrfK3lr1T1WF20HhWdHcesENX',
#     'name': 'Dancing Goats Coffee Emory',
#     'url': 'https://www.dancinggoats.com/pages/atlanta-cafes',
#     'entityPresentationInfo': {'entityScenario': 'ListItem',
#      'entityTypeHints': ['Place', 'LocalBusiness', 'Restaurant']},
#     'address': {'addressLocality': 'Atlanta',
#      'addressRegion': 'Ga',
#      'postalCode': '30322',
#      'addressCountry': 'US',
#      'neighborhood': 'Clifton Community'},
#     'telephone': '(404) 727-7094'},
#    {'_type': 'Restaurant',
#     'id': 'https://api.bing.microsoft.com/api/v7/#Places.4',
#     'webSearchUrl': 'https://www.bing.com/entityexplore?q=Dancing+Goats+Coffee&filters=local_ypid:%22YN873x17927439471315774259%22&elv=AXXfrEiqqD9r3GuelwApulo0yQBvlWmiSDFuzbR1VfWxCeTcTGywG0HfmgdJmstn3gM9FLZvdaqLBdHZidtXrfK3lr1T1WF20HhWdHcesENX',
#     'name': 'Dancing Goats Coffee',
#     'url': 'https://www.dancinggoats.com/pages/locations',
#     'entityPresentationInfo': {'entityScenario': 'ListItem',
#      'entityTypeHints': ['Place', 'LocalBusiness', 'Restaurant']},
#     'address': {'addressLocality': 'Atlanta',
#      'addressRegion': 'GA',
#      'postalCode': '30309',
#      'addressCountry': 'US',
#      'neighborhood': ''},
#     'telephone': '(404) 600-6547'}]},
#  'rankingResponse': {'mainline': {'items': [{'answerType': 'WebPages',
#      'resultIndex': 0,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.0'}},
#     {'answerType': 'Places'},
#     {'answerType': 'Places',
#      'resultIndex': 0,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#Places.0'}},
#     {'answerType': 'Places',
#      'resultIndex': 1,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#Places.1'}},
#     {'answerType': 'Places',
#      'resultIndex': 2,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#Places.2'}},
#     {'answerType': 'Places',
#      'resultIndex': 3,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#Places.3'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 1,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.1'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 2,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.2'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 3,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.3'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 4,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.4'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 5,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.5'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 6,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.6'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 7,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.7'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 8,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.8'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 9,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.9'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 10,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.10'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 11,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.11'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 12,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.12'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 13,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.13'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 14,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.14'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 15,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.15'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 16,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.16'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 17,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.17'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 18,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.18'}},
#     {'answerType': 'WebPages',
#      'resultIndex': 19,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.19'}}]},
#   'sidebar': {'items': [{'answerType': 'Places',
#      'resultIndex': 4,
#      'value': {'id': 'https://api.bing.microsoft.com/api/v7/#Places.4'}}]}}}

# %%
website_info = ""
for key, value in urls.items():
    print(f"Contents of the website of {key} with url {value}")
    result = site_scraper.scrape_webpage(value)
    print(len(result))
    website_info = website_info + f"\n contents from website with name: {key}" + result
# Out:
# Contents of the website of Bizapedia with url https://www.bizapedia.com/addresses/200-market-st-ne-olympia-wa-98501.html
# 3699
# Contents of the website of OpenCorporates with url https://opencorporates.com/companies/us_pa/2639070
# 2993
# Contents of the website of Georgia Company Directory with url https://www.georgiacompanyregistry.com/companies/dancing-goats-coffee-arr-llc/
# 8565
# Contents of the website of Dun & Bradstreet with url https://www.dnb.com/contact-directory/contact-profile.zoe.cb802a4479b3264f89a76231ec17f223.html
# 1435
# Contents of the website of Dancing Goats® Coffee with url https://www.dancinggoats.com/pages/wholesale-info
# 8983
# Contents of the website of MenuPix with url https://www.menupix.com/atlanta/restaurants/31628996/Dancing-Goats-Coffee-Bar-Atlanta-GA
# 8988
# Contents of the website of Buzzfile with url https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391
# Error fetching the URL: 403 Client Error: Forbidden for url: https://www.buzzfile.com/business/Dancing-Goats-Coffee-Arr,-LLC-360-753-3391
# 2954

# %%
website_info
# Out:
# "\n contents from website with name: Bizapedia\n\n\n\n\n\n200 Market St Ne Olympia, WA 98501-6965 - Bizapedia Address Profile\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n200 MARKET ST NE OLYMPIA, WA 98501-6965\nSponsored Links\n\n\n\n\n\n\n\n\nThere are 9 companies that have an address matching 200 Market St Ne Olympia, WA 98501-6965.\nThe companies are Challain Inc Spc, Challain Inc, Dgcb Atl Ponce City Market LLC, Dgcb Atl 33 Peachtree Place LLC, Dgcb Atl Buckhead Exchange LLC, Tdgcb LLC, Challain Inc, Dancing Goats Coffee Arr LLC, and Dancing Goats Coffee.\nCHALLAIN, INC., SPC\nWASHINGTON WA SOCIAL PURPOSE CORPORATION\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal, Mailing, and Registered Agent\nRegistered\xa0Agent:\xa0\xa0\nDavid J Wasson\nFiled:\xa0\xa0\nMay 21, 1990\nFile\xa0Number:\xa0\xa0\n601250414\nContact Us About The Company Profile For Challain, Inc., Spc\nCHALLAIN, INC.\nFLORIDA FOREIGN PROFIT CORPORATION\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal and Mailing\nRegistered\xa0Agent:\xa0\xa0\nCross Street Corporate Services, LLC\nFiled:\xa0\xa0\nOctober 23, 2014\nFile\xa0Number:\xa0\xa0\nF14000004514\nContact Us About The Company Profile For Challain, Inc.\nSponsored Links\n\n\n\n\n\n\n\n\nDGCB ATL PONCE CITY MARKET, LLC\nGEORGIA DOMESTIC LIMITED-LIABILITY COMPANY\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal\nRegistered\xa0Agent:\xa0\xa0\nBob Goldberg\nFiled:\xa0\xa0\nJune 04, 2015\nFile\xa0Number:\xa0\xa0\n15057821\nContact Us About The Company Profile For Dgcb Atl Ponce City Market, LLC\nDGCB ATL 33 PEACHTREE PLACE, LLC\nGEORGIA DOMESTIC LIMITED-LIABILITY COMPANY\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal\nRegistered\xa0Agent:\xa0\xa0\nBob Goldberg\nFiled:\xa0\xa0\nJune 04, 2015\nFile\xa0Number:\xa0\xa0\n15057822\nContact Us About The Company Profile For Dgcb Atl 33 Peachtree Place, LLC\nDGCB ATL BUCKHEAD EXCHANGE, LLC\nGEORGIA DOMESTIC LIMITED-LIABILITY COMPANY\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal\nRegistered\xa0Agent:\xa0\xa0\nBob J. Goldberg\nFiled:\xa0\xa0\nFebruary 15, 2017\nFile\xa0Number:\xa0\xa0\n17020112\nContact Us About The Company Profile For Dgcb Atl Buckhead Exchange, LLC\nTDGCB, LLC\nWASHINGTON WA LIMITED-LIABILITY COMPANY\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nRegistered Agent\nRegistered\xa0Agent:\xa0\xa0\nDavid Wasson\nFiled:\xa0\xa0\nDecember 06, 2019\nFile\xa0Number:\xa0\xa0\n604551020\nContact Us About The Company Profile For Tdgcb, LLC\nCHALLAIN, INC.\nGEORGIA FOREIGN PROFIT CORPORATION\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal\nRegistered\xa0Agent:\xa0\xa0\nNational Registered Agents, Inc.\nFiled:\xa0\xa0\nNovember 15, 2011\nFile\xa0Number:\xa0\xa0\n11087291\nContact Us About The Company Profile For Challain, Inc.\nDANCING GOATS COFFEE ARR, LLC\nGEORGIA DOMESTIC LIMITED-LIABILITY COMPANY\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nPrincipal\nRegistered\xa0Agent:\xa0\xa0\nBob J Goldberg\nFiled:\xa0\xa0\nJuly 05, 2022\nFile\xa0Number:\xa0\xa0\n22146246\nContact Us About The Company Profile For Dancing Goats Coffee Arr, LLC\nDANCING GOATS COFFEE\nFLORIDA ASSUMED NAME\nWRITE REVIEW\nAddress:\xa0\xa0\n200 Market St Ne\nOlympia, WA 98501-6965 \nAddress\xa0Types:\xa0\xa0\nOfficer\nRegistered\xa0Agent:\xa0\xa0\nFiled:\xa0\xa0\nJuly 12, 2024\nFile\xa0Number:\xa0\xa0\nG24000083525\nContact Us About The Company Profile For Dancing Goats Coffee\nSponsored Links\n\n\n\n\n\n\n\n\nADDITIONAL LINKS\nSearch All Addresses\n(Displaying 9 matche ...

# %% [markdown]
# Clean text

# %%
import re
def clean_text(text):
    # Replace multiple newlines with a single newline
    text = re.sub(r'\n+', '\n', text)
    # Remove leading/trailing whitespace from each line
    text = '\n'.join(line.strip() for line in text.splitlines())
    # Remove extra spaces between words
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
cleaned_text = clean_text(website_info)
print(cleaned_text)
# Out:
#  contents from website with name: Bizapedia 200 Market St Ne Olympia, WA 98501-6965 - Bizapedia Address Profile 200 MARKET ST NE OLYMPIA, WA 98501-6965 Sponsored Links There are 9 companies that have an address matching 200 Market St Ne Olympia, WA 98501-6965. The companies are Challain Inc Spc, Challain Inc, Dgcb Atl Ponce City Market LLC, Dgcb Atl 33 Peachtree Place LLC, Dgcb Atl Buckhead Exchange LLC, Tdgcb LLC, Challain Inc, Dancing Goats Coffee Arr LLC, and Dancing Goats Coffee. CHALLAIN, INC., SPC WASHINGTON WA SOCIAL PURPOSE CORPORATION WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal, Mailing, and Registered Agent Registered Agent: David J Wasson Filed: May 21, 1990 File Number: 601250414 Contact Us About The Company Profile For Challain, Inc., Spc CHALLAIN, INC. FLORIDA FOREIGN PROFIT CORPORATION WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal and Mailing Registered Agent: Cross Street Corporate Services, LLC Filed: October 23, 2014 File Number: F14000004514 Contact Us About The Company Profile For Challain, Inc. Sponsored Links DGCB ATL PONCE CITY MARKET, LLC GEORGIA DOMESTIC LIMITED-LIABILITY COMPANY WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal Registered Agent: Bob Goldberg Filed: June 04, 2015 File Number: 15057821 Contact Us About The Company Profile For Dgcb Atl Ponce City Market, LLC DGCB ATL 33 PEACHTREE PLACE, LLC GEORGIA DOMESTIC LIMITED-LIABILITY COMPANY WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal Registered Agent: Bob Goldberg Filed: June 04, 2015 File Number: 15057822 Contact Us About The Company Profile For Dgcb Atl 33 Peachtree Place, LLC DGCB ATL BUCKHEAD EXCHANGE, LLC GEORGIA DOMESTIC LIMITED-LIABILITY COMPANY WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal Registered Agent: Bob J. Goldberg Filed: February 15, 2017 File Number: 17020112 Contact Us About The Company Profile For Dgcb Atl Buckhead Exchange, LLC TDGCB, LLC WASHINGTON WA LIMITED-LIABILITY COMPANY WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Registered Agent Registered Agent: David Wasson Filed: December 06, 2019 File Number: 604551020 Contact Us About The Company Profile For Tdgcb, LLC CHALLAIN, INC. GEORGIA FOREIGN PROFIT CORPORATION WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal Registered Agent: National Registered Agents, Inc. Filed: November 15, 2011 File Number: 11087291 Contact Us About The Company Profile For Challain, Inc. DANCING GOATS COFFEE ARR, LLC GEORGIA DOMESTIC LIMITED-LIABILITY COMPANY WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Principal Registered Agent: Bob J Goldberg Filed: July 05, 2022 File Number: 22146246 Contact Us About The Company Profile For Dancing Goats Coffee Arr, LLC DANCING GOATS COFFEE FLORIDA ASSUMED NAME WRITE REVIEW Address: 200 Market St Ne Olympia, WA 98501-6965 Address Types: Officer Registered Agent: Filed: July 12, 2024 File Number: G24000083525 Contact Us About The Company Profile For Dancing Goats Coffee Sponsored Links ADDITIONAL LINKS Search All Addresses (Displaying 9 matches) The information on this page is being provided for the purpose of informing the public about a matter of genuine public interest. Copyright © 2012-2024 · Bizapedia.com · All rights reserved. Pro Data Pro Search Pro API Contact Us Terms of Use Privacy Policy Sitemap Desktop · Server 1 contents from website with name: OpenCorporates DANCING GOATS COFFEE COMPANY :: Pennsylvania (US) :: OpenCorporates The Open Database Of The Corporate World Search Companies Officers Log in/Sign up DANCING GOATS COFFEE COMPANY branch Company Number 2639070 Status Active Incorporation Date Please log in to see this data Company Type Foreign Business Corporation Jurisdiction Pennsylvania (US) Branch Branch of DANCING GOATS COFFEE COMPANY (De ...
